# %%
import numpy as np
import pandas as pd
import os
import pickle
import gc
import re

import pandas_profiling as pdp

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
import lightgbm as lgb

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/train.csv')
test = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/test.csv')
sub = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/sample_submit.csv')

# %%
class cfg:
  n_splits = 5

  seed = 123

  num_round = 100

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'learning_rate': 0.02,
    'num_leaves': 16,
    'm_estimators': 100000,
    'random_state': cfg.seed,
    'importance_type': 'gain',
}

# %%
def cleaning(texts):
  clean_texts = []
  for text in texts:
    text = remove_tag(text)
    clean_texts.append(text)
  return clean_texts

def remove_tag(x):
  p = re.compile(r"<[^>]*?>")
  return p.sub('',x)

# %%
fold = pd.DataFrame(np.load("/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Oututput/test-2-bert-deberta-base-epoch10/preds/oof_pred.npy"))
print(fold.shape)
fold
# Out:
# (9791, 4)
#              0         1         2         3
# 0     0.943848  0.938477  0.013741  0.010490
# 1     0.991699  0.664551  0.018234  0.015839
# 2     0.978027  0.987793  0.028488  0.036438
# 3     0.982910  0.987305  0.036285  0.023911
# 4     0.865234  0.995605  0.014061  0.009857
# ...        ...       ...       ...       ...
# 9786  0.966309  0.962402  0.012825  0.014229
# 9787  0.994629  0.718750  0.006851  0.008255
# 9788  0.990723  0.940918  0.057190  0.049683
# 9789  0.974609  0.989746  0.035065  0.042572
# 9790  0.986328  0.971680  0.035339  0.027908
#
# [9791 rows x 4 columns]

# %%
# df_text = train[['html_content']]
# df_text['html_content'] = cleaning(df_text['html_content'])
# print(df_text.shape)

# vec = CountVectorizer(min_df=200)

# vec.fit(df_text['html_content'])

# html_content = pd.DataFrame(vec.transform(df_text['html_content']).toarray(), columns=vec.get_feature_names())
# print(html_content.shape)
# html_content

# %%
x_train = train[['goal', 'country', 'duration', 'category1', 'category2']]
x_train.columns = ['goal1', 'country1', 'duration1', 'category1', 'category2']
# x_train = train[['duration']]
y_train = train['state']
id_train = train['id']
categorical_features = ['goal1', 'country1', 'category1', 'category2']

cv = list(StratifiedKFold(n_splits=cfg.n_splits, shuffle=True, random_state=cfg.seed).split(x_train, y_train))


metrics = []
imp = pd.DataFrame()

for column in categorical_features:
  target_column = x_train[column]
  le = LabelEncoder()
  le.fit(target_column)
  label_encoded_column = le.transform(target_column)
  x_train[column] = pd.Series(label_encoded_column).astype('category')

# print(x_train.shape)
# x_train = pd.concat([x_train, html_content], axis=1)
print(x_train.shape)
x_train = pd.concat([x_train, fold], axis=1)
print(x_train.shape)

for nfold in range(cfg.n_splits):
  print('-'*20, nfold, '-'*20)
  idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
  x_tr, y_tr = x_train.loc[idx_tr], y_train.loc[idx_tr]
  x_va, y_va = x_train.loc[idx_va], y_train.loc[idx_va]
  print(x_tr.shape, y_tr.shape)
  print(x_va.shape, y_va.shape)

  lgb_tr = lgb.Dataset(x_tr, y_tr)
  lgb_va = lgb.Dataset(x_va, y_va)

  lgb_results = {}
  model = lgb.train(params, lgb_tr, num_boost_round=cfg.num_round,
                    valid_names=['train', 'valid'],
                    valid_sets=[lgb_tr, lgb_va])

  y_tr_pred = model.predict(x_tr)
  y_va_pred = model.predict(x_va)
  y_tr_pred = np.where(y_tr_pred > 0.5, 1, 0)
  y_va_pred = np.where(y_va_pred > 0.5, 1, 0)

  print(y_tr)
  print(y_tr_pred)
  f1_tr = f1_score(y_tr, y_tr_pred)
  f1_va = f1_score(y_va, y_va_pred)
  print('[f1 score] tr:{:.2f}, va:{:.2f}'.format(f1_tr, f1_va))
  metrics.append([nfold, f1_tr, f1_va])

print('='*20, 'result', '='*20)
metrics = np.array(metrics)
print(metrics)
# Out:
# (9791, 5)
# (9791, 9)
# -------------------- 0 --------------------
# (7832, 9) (7832,)
# (1959, 9) (1959,)
# [1]	train's binary_logloss: 0.684985	valid's binary_logloss: 0.685458
# [2]	train's binary_logloss: 0.677202	valid's binary_logloss: 0.678088
# [3]	train's binary_logloss: 0.669709	valid's binary_logloss: 0.670901
# [4]	train's binary_logloss: 0.662405	valid's binary_logloss: 0.663966
# [5]	train's binary_logloss: 0.655408	valid's binary_logloss: 0.657417
# [6]	train's binary_logloss: 0.648652	valid's binary_logloss: 0.651078
# [7]	train's binary_logloss: 0.64215	valid's binary_logloss: 0.64494
# [8]	train's binary_logloss: 0.635848	valid's binary_logloss: 0.639
# [9]	train's binary_logloss: 0.629729	valid's binary_logloss: 0.633308
# [10]	train's binary_logloss: 0.623884	valid's binary_logloss: 0.627891
# [11]	train's binary_logloss: 0.618126	valid's binary_logloss: 0.622408
# [12]	train's binary_logloss: 0.612517	valid's binary_logloss: 0.617039
# [13]	train's binary_logloss: 0.6071	valid's binary_logloss: 0.612065
# [14]	train's binary_logloss: 0.601865	valid's binary_logloss: 0.607263
# [15]	train's binary_logloss: 0.596784	valid's binary_logloss: 0.602561
# [16]	train's binary_logloss: 0.591802	valid's binary_logloss: 0.597978
# [17]	train's binary_logloss: 0.587021	valid's binary_logloss: 0.593551
# [18]	train's binary_logloss: 0.582308	valid's binary_logloss: 0.589244
# [19]	train's binary_logloss: 0.577729	valid's binary_logloss: 0.584973
# [20]	train's binary_logloss: 0.573383	valid's binary_logloss: 0.580944
# [21]	train's binary_logloss: 0.569169	valid's binary_logloss: 0.577092
# [22]	train's binary_logloss: 0.565014	valid's binary_logloss: 0.573269
# [23]	train's binary_logloss: 0.560892	valid's binary_logloss: 0.569607
# [24]	train's binary_logloss: 0.556834	valid's binary_logloss: 0.565832
# [25]	train's binary_logloss: 0.552911	valid's binary_logloss: 0.562406
# [26]	train's binary_logloss: 0.549101	valid's binary_logloss: 0.559108
# [27]	train's binary_logloss: 0.545319	valid's binary_logloss: 0.555863
# [28]	train's binary_logloss: 0.541718	valid's binary_logloss: 0.5526
# [29]	train's binary_logloss: 0.538333	valid's binary_logloss: 0.549619
# [30]	train's binary_logloss: 0.534981	valid's binary_logloss: 0.546735
# [31]	train's binary_logloss: 0.531697	valid's binary_logloss: 0.543794
# [32]	train's binary_logloss: 0.528558	valid's binary_logloss: 0.541027
# [33]	train's binary_logloss: 0.525283	valid's binary_logloss: 0.538186
# [34]	train's binary_logloss: 0.522209	valid's binary_logloss: 0.535554
# [35]	train's binary_logloss: 0.519185	valid's binary_logloss: 0.532939
# [36]	train's binary_logloss: 0.51625	valid's binary_logloss: 0.530447
# [37]	train's binary_logloss: 0.513428	valid's binary_logloss: 0.528047
# [38]	train's binary_logloss: 0.510759	valid's binary_logloss: 0.525695
# [39]	train's binary_logloss: 0.507994	valid's binary_logloss: 0.523454
# [40]	train's binary_logloss: 0.505308	valid's binary_logloss: 0.521118
# [41]	train's binary_logloss: 0.502697	valid's binary_logloss: 0.518965
# [42]	train's binary_logloss: 0.500114	valid's binary_logloss: 0.516734
# [43]	train's binary_logloss: 0.497625	valid's binary_logloss: 0.514707
# [44]	train's binary_logloss: 0.495157	valid's binary_logloss: 0.512656
# [45]	train's binary_logloss: 0.492785	valid's binary_logloss: 0.510783
# [46]	train's binary_logloss: 0.490522	valid's binary_logloss: 0.508928
# [47]	train's binary_logloss: 0.488289	valid's binary_logloss: 0.507015
# [48]	train's binary_logloss: 0.486063	valid's binary_logloss: 0.505059
# [49]	train's binary_logloss: 0.483905	valid's binary_logloss: 0.50333
# [50]	train's binary_logloss: 0.481803	valid's binary_logloss: 0.501576
# [51]	train's binary_logloss: 0.479779	valid's binary_logloss: 0.499845
# [52]	train's binary_logloss: 0.477763	valid's binary_logloss: 0.498212
# [53]	train's binary_logloss: 0.475774	valid's binary_logloss: 0.496698
# [54]	train's binary_logloss: 0.473865	valid's binary_logloss: 0.495059
# [55]	train's binary_logloss: 0.471947	valid's binary_logloss: 0.493526
# [56]	train's binary_logloss: 0.470073	valid's binary_logloss: 0.49207
# [57]	train's binary_logloss: 0.468245	valid's binary_logloss: 0.490559
# [58]	train's binary_logloss: 0.466443	valid's binary_logloss: 0.489232
# [59]	train's binary_logloss: 0.464687	valid's binary_logloss: 0.487919
# [60]	train's binary_logloss: 0.462925	valid's binary_logloss: 0.4865
# [61]	train's binary_logloss: 0.461277	valid's binary_logloss: 0.485303
# [62]	train's binary_logloss: 0.459642	valid's binary_logloss: 0.483997
# [63]	train's binary_logloss: 0.458027	valid's binary_logloss: 0.482804
# [64]	train's binary_logloss: 0.456442	valid's binary_logloss: 0.48155
# [65]	train's binary_logloss: 0.454895	valid's binary_logloss: 0.480482
# [66]	train's binary_logloss: 0.453345	valid's binary_logloss: 0.479399
# [67]	train's binary_logloss: 0.451803	valid's binary_logloss: 0.478244
# [68]	train's binary_logloss: 0.450298	valid's binary_logloss: 0.477102
# [69]	train's binary_logloss: 0.448857	valid's binary_logloss: 0.475988
# [70]	train's binary_logloss: 0.447401	valid's binary_logloss: 0.474815
# [71]	train's binary_logloss: 0.44598	valid's binary_logloss: 0.473687
# [72]	train's binary_logloss: 0.444548	valid's binary_logloss: 0.472567
# [73]	train's binary_logloss: 0.443223	valid's binary_logloss: 0.471718
# [74]	train's binary_logloss: 0.44176	valid's binary_logloss: 0.470646
# [75]	train's binary_logloss: 0.440419	valid's binary_logloss: 0.469642
# [76]	train's binary_logloss: 0.439009	valid's binary_logloss: 0.468638
# [77]	train's binary_logloss: 0.437653	valid's binary_logloss: 0.467614
# [78]	train's binary_logloss: 0.436404	valid's binary_logloss: 0.466676
# [79]	train's binary_logloss: 0.435071	valid's binary_logloss: 0.465725
# [80]	train's binary_logloss: 0.433869	valid's binary_logloss: 0.46472
# [81]	train's binary_logloss: 0.432674	valid's binary_logloss: 0.463908
# [82]	train's binary_logloss: 0.431517	valid's binary_logloss: 0.463093
# [83]	train's binary_logloss: 0.430392	valid's binary_logloss: 0.462318
# [84]	train's binary_logloss: 0.429192	valid's binary_logloss: 0.461452
# [85]	train's binary_logloss: 0.428038	valid's binary_logloss: 0.460678
# [86]	train's binary_logloss: 0.426896	valid's binary_logloss: 0.459893
# [87]	train's binary_logloss: 0.42575	valid's binary_logloss: 0.459015
# [88]	train's binary_logloss: 0.424686	valid's binary_logloss: 0.45821
# [89]	train's binary_logloss: 0.423588	valid's binary_logloss: 0.457385
# [90]	train's binary_logloss: 0.422515	valid's binary_logloss: 0.45656
# [91]	train's binary_logloss: 0.421459	valid's binary_logloss: 0.455885
# [92]	train's binary_logloss: 0.420509	valid's binary_logloss: 0.455432
# [93]	train's binary_logloss: 0.419482	valid's binary_logloss: 0.454765
# [94]	train's binary_logloss: 0.418544	valid's binary_logloss: 0.454153
# [95]	train's binary_logloss: 0.417636	valid's binary_logloss: 0.453598
# [96]	train's binary_logloss: 0.41668	valid's binary_logloss: 0.452948
# [97]	train's binary_logloss: 0.415764	valid's binary_logloss: 0.452289
# [98]	train's binary_logloss: 0.414867	valid's binary_logloss: 0.451667
# [99]	train's binary_logloss: 0.413925	valid's binary_logloss: 0.450979
# [100]	train's binary_logloss: 0.413006	valid's binary_logloss: 0.450438
# 0       1
# 2       0
# 3       1
# 4       1
# 5       0
#        ..
# 9785    0
# 9786    0
# 9788    0
# 9789    1
# 9790    0
# Name: state, Length: 7832, dtype: int64
# [0 1 1 ... 0 1 0]
# [f1 score] tr:0.82, va:0.78
# -------------------- 1 --------------------
# (7833, 9) (7833,)
# (1958, 9) (1958,)
# [1]	train's binary_logloss: 0.685013	valid's binary_logloss: 0.68532
# [2]	train's binary_logloss: 0.677276	valid's binary_logloss: 0.677897
# [3]	train's binary_logloss: 0.669833	valid's binary_logloss: 0.670776
# [4]	train's binary_logloss: 0.662652	valid's binary_logloss: 0.663845
# [5]	train's binary_logloss: 0.655649	valid's binary_logloss: 0.657202
# [6]	train's binary_logloss: 0.648946	valid's binary_logloss: 0.650867
# [7]	train's binary_logloss: 0.642462	valid's binary_logloss: 0.644746
# [8]	train's binary_logloss: 0.636226	valid's binary_logloss: 0.638878
# [9]	train's binary_logloss: 0.630176	valid's binary_logloss: 0.633213
# [10]	train's binary_logloss: 0.624329	valid's binary_logloss: 0.627795
# [11]	train's binary_logloss: 0.618619	valid's binary_logloss: 0.622387
# [12]	train's binary_logloss: 0.613136	valid's binary_logloss: 0.617201
# [13]	train's binary_logloss: 0.607778	valid's binary_logloss: 0.612259
# [14]	train's binary_logloss: 0.602624	valid's binary_logloss: 0.60744
# [15]	train's binary_logloss: 0.59751	valid's binary_logloss: 0.602619
# [16]	train's binary_logloss: 0.592582	valid's binary_logloss: 0.598052
# [17]	train's binary_logloss: 0.58782	valid's binary_logloss: 0.59374
# [18]	train's binary_logloss: 0.583126	valid's binary_logloss: 0.589622
# [19]	train's binary_logloss: 0.57863	valid's binary_logloss: 0.585656
# [20]	train's binary_logloss: 0.574347	valid's binary_logloss: 0.581773
# [21]	train's binary_logloss: 0.569949	valid's binary_logloss: 0.577765
# [22]	train's binary_logloss: 0.56571	valid's binary_logloss: 0.573973
# [23]	train's binary_logloss: 0.561596	valid's binary_logloss: 0.570281
# [24]	train's binary_logloss: 0.557726	valid's binary_logloss: 0.566714
# [25]	train's binary_logloss: 0.553798	valid's binary_logloss: 0.563046
# [26]	train's binary_logloss: 0.550025	valid's binary_logloss: 0.559701
# [27]	train's binary_logloss: 0.546325	valid's binary_logloss: 0.556331
# [28]	train's binary_logloss: 0.542738	valid's binary_logloss: 0.553178
# [29]	train's binary_logloss: 0.539302	valid's binary_logloss: 0.550076
# [30]	train's binary_logloss: 0.536055	valid's binary_logloss: 0.547091
# [31]	train's binary_logloss: 0.532738	valid's binary_logloss: 0.544186
# [32]	train's binary_logloss: 0.529583	valid's binary_logloss: 0.541423
# [33]	train's binary_logloss: 0.526486	valid's binary_logloss: 0.538718
# [34]	train's binary_logloss: 0.52344	valid's binary_logloss: 0.535964
# [35]	train's binary_logloss: 0.520498	valid's binary_logloss: 0.533413
# [36]	train's binary_logloss: 0.517577	valid's binary_logloss: 0.530817
# [37]	train's binary_logloss: 0.514711	valid's binary_logloss: 0.528321
# [38]	train's binary_logloss: 0.511927	valid's binary_logloss: 0.525878
# [39]	train's binary_logloss: 0.509189	valid's binary_logloss: 0.523537
# [40]	train's binary_logloss: 0.506497	valid's binary_logloss: 0.521211
# [41]	train's binary_logloss: 0.503841	valid's binary_logloss: 0.518939
# [42]	train's binary_logloss: 0.501255	valid's binary_logloss: 0.516617
# [43]	train's binary_logloss: 0.498727	valid's binary_logloss: 0.514521
# [44]	train's binary_logloss: 0.496285	valid's binary_logloss: 0.512408
# [45]	train's binary_logloss: 0.493827	valid's binary_logloss: 0.51025
# [46]	train's binary_logloss: 0.491523	valid's binary_logloss: 0.508329
# [47]	train's binary_logloss: 0.48928	valid's binary_logloss: 0.506453
# [48]	train's binary_logloss: 0.487074	valid's binary_logloss: 0.504485
# [49]	train's binary_logloss: 0.484946	valid's binary_logloss: 0.502756
# [50]	train's binary_logloss: 0.482817	valid's binary_logloss: 0.500977
# [51]	train's binary_logloss: 0.480754	valid's binary_logloss: 0.499171
# [52]	train's binary_logloss: 0.478711	valid's binary_logloss: 0.497389
# [53]	train's binary_logloss: 0.476676	valid's binary_logloss: 0.495716
# [54]	train's binary_logloss: 0.474735	valid's binary_logloss: 0.494099
# [55]	train's binary_logloss: 0.472757	valid's binary_logloss: 0.492504
# [56]	train's binary_logloss: 0.470883	valid's binary_logloss: 0.490797
# [57]	train's binary_logloss: 0.46906	valid's binary_logloss: 0.489315
# [58]	train's binary_logloss: 0.467285	valid's binary_logloss: 0.487816
# [59]	train's binary_logloss: 0.46557	valid's binary_logloss: 0.486451
# [60]	train's binary_logloss: 0.463875	valid's binary_logloss: 0.484956
# [61]	train's binary_logloss: 0.4622	valid's binary_logloss: 0.483641
# [62]	train's binary_logloss: 0.460541	valid's binary_logloss: 0.482391
# [63]	train's binary_logloss: 0.458882	valid's binary_logloss: 0.480992
# [64]	train's binary_logloss: 0.457265	valid's binary_logloss: 0.479631
# [65]	train's binary_logloss: 0.455707	valid's binary_logloss: 0.478232
# [66]	train's binary_logloss: 0.454176	valid's binary_logloss: 0.477022
# [67]	train's binary_logloss: 0.452621	valid's binary_logloss: 0.475753
# [68]	train's binary_logloss: 0.451158	valid's binary_logloss: 0.474518
# [69]	train's binary_logloss: 0.449674	valid's binary_logloss: 0.473227
# [70]	train's binary_logloss: 0.448228	valid's binary_logloss: 0.472127
# [71]	train's binary_logloss: 0.446832	valid's binary_logloss: 0.470999
# [72]	train's binary_logloss: 0.445454	valid's binary_logloss: 0.469992
# [73]	train's binary_logloss: 0.444101	valid's binary_logloss: 0.468768
# [74]	train's binary_logloss: 0.44273	valid's binary_logloss: 0.467859
# [75]	train's binary_logloss: 0.44141	valid's binary_logloss: 0.46699
# [76]	train's binary_logloss: 0.440133	valid's binary_logloss: 0.466003
# [77]	train's binary_logloss: 0.438873	valid's binary_logloss: 0.465013
# [78]	train's binary_logloss: 0.437633	valid's binary_logloss: 0.464092
# [79]	train's binary_logloss: 0.43643	valid's binary_logloss: 0.463314
# [80]	train's binary_logloss: 0.435239	valid's binary_logloss: 0.462268
# [81]	train's binary_logloss: 0.434069	valid's binary_logloss: 0.461473
# [82]	train's binary_logloss: 0.4329	valid's binary_logloss: 0.460743
# [83]	train's binary_logloss: 0.431717	valid's binary_logloss: 0.459828
# [84]	train's binary_logloss: 0.430569	valid's binary_logloss: 0.458831
# [85]	train's binary_logloss: 0.429435	valid's binary_logloss: 0.458058
# [86]	train's binary_logloss: 0.428314	valid's binary_logloss: 0.457351
# [87]	train's binary_logloss: 0.427234	valid's binary_logloss: 0.456665
# [88]	train's binary_logloss: 0.426202	valid's binary_logloss: 0.455872
# [89]	train's binary_logloss: 0.425208	valid's binary_logloss: 0.455243
# [90]	train's binary_logloss: 0.424189	valid's binary_logloss: 0.454611
# [91]	train's binary_logloss: 0.423151	valid's binary_logloss: 0.453887
# [92]	train's binary_logloss: 0.422128	valid's binary_logloss: 0.453075
# [93]	train's binary_logloss: 0.42112	valid's binary_logloss: 0.452392
# [94]	train's binary_logloss: 0.420142	valid's binary_logloss: 0.451735
# [95]	train's binary_logloss: 0.419197	valid's binary_logloss: 0.451057
# [96]	train's binary_logloss: 0.418197	valid's binary_logloss: 0.450402
# [97]	train's binary_logloss: 0.417277	valid's binary_logloss: 0.449743
# [98]	train's binary_logloss: 0.416321	valid's binary_logloss: 0.449086
# [99]	train's binary_logloss: 0.415403	valid's binary_logloss: 0.448367
# [100]	train's binary_logloss: 0.414417	valid's binary_logloss: 0.447818
# 1       0
# 3       1
# 4       1
# 5       0
# 7       0
#        ..
# 9785    0
# 9786    0
# 9787    0
# 9788    0
# 9789    1
# Name: state, Length: 7833, dtype: int64
# [0 1 1 ... 0 0 1]
# [f1 score] tr:0.81, va:0.78
# -------------------- 2 --------------------
# (7833, 9) (7833,)
# (1958, 9) (1958,)
# [1]	train's binary_logloss: 0.684875	valid's binary_logloss: 0.685518
# [2]	train's binary_logloss: 0.677026	valid's binary_logloss: 0.678327
# [3]	train's binary_logloss: 0.669477	valid's binary_logloss: 0.671415
# [4]	train's binary_logloss: 0.662192	valid's binary_logloss: 0.664812
# [5]	train's binary_logloss: 0.655199	valid's binary_logloss: 0.658469
# [6]	train's binary_logloss: 0.648333	valid's binary_logloss: 0.652199
# [7]	train's binary_logloss: 0.641714	valid's binary_logloss: 0.646192
# [8]	train's binary_logloss: 0.635407	valid's binary_logloss: 0.640424
# [9]	train's binary_logloss: 0.629257	valid's binary_logloss: 0.634882
# [10]	train's binary_logloss: 0.623321	valid's binary_logloss: 0.629543
# [11]	train's binary_logloss: 0.61756	valid's binary_logloss: 0.624384
# [12]	train's binary_logloss: 0.612009	valid's binary_logloss: 0.619337
# [13]	train's binary_logloss: 0.606612	valid's binary_logloss: 0.614358
# [14]	train's binary_logloss: 0.601442	valid's binary_logloss: 0.609636
# [15]	train's binary_logloss: 0.596299	valid's binary_logloss: 0.604989
# [16]	train's binary_logloss: 0.59131	valid's binary_logloss: 0.600505
# [17]	train's binary_logloss: 0.586539	valid's binary_logloss: 0.596272
# [18]	train's binary_logloss: 0.581834	valid's binary_logloss: 0.591938
# [19]	train's binary_logloss: 0.57724	valid's binary_logloss: 0.587764
# [20]	train's binary_logloss: 0.57283	valid's binary_logloss: 0.583711
# [21]	train's binary_logloss: 0.568505	valid's binary_logloss: 0.579813
# [22]	train's binary_logloss: 0.564314	valid's binary_logloss: 0.576023
# [23]	train's binary_logloss: 0.560092	valid's binary_logloss: 0.572255
# [24]	train's binary_logloss: 0.556043	valid's binary_logloss: 0.568576
# [25]	train's binary_logloss: 0.552089	valid's binary_logloss: 0.565071
# [26]	train's binary_logloss: 0.548254	valid's binary_logloss: 0.561625
# [27]	train's binary_logloss: 0.5446	valid's binary_logloss: 0.558449
# [28]	train's binary_logloss: 0.541062	valid's binary_logloss: 0.555351
# [29]	train's binary_logloss: 0.537517	valid's binary_logloss: 0.552236
# [30]	train's binary_logloss: 0.534139	valid's binary_logloss: 0.549302
# [31]	train's binary_logloss: 0.530804	valid's binary_logloss: 0.546391
# [32]	train's binary_logloss: 0.527515	valid's binary_logloss: 0.543611
# [33]	train's binary_logloss: 0.524419	valid's binary_logloss: 0.541005
# [34]	train's binary_logloss: 0.521343	valid's binary_logloss: 0.538409
# [35]	train's binary_logloss: 0.518259	valid's binary_logloss: 0.535772
# [36]	train's binary_logloss: 0.515202	valid's binary_logloss: 0.533255
# [37]	train's binary_logloss: 0.512255	valid's binary_logloss: 0.530798
# [38]	train's binary_logloss: 0.509405	valid's binary_logloss: 0.52839
# [39]	train's binary_logloss: 0.506684	valid's binary_logloss: 0.526187
# [40]	train's binary_logloss: 0.504013	valid's binary_logloss: 0.523988
# [41]	train's binary_logloss: 0.501385	valid's binary_logloss: 0.521819
# [42]	train's binary_logloss: 0.498798	valid's binary_logloss: 0.519751
# [43]	train's binary_logloss: 0.49628	valid's binary_logloss: 0.517586
# [44]	train's binary_logloss: 0.493867	valid's binary_logloss: 0.51568
# [45]	train's binary_logloss: 0.491486	valid's binary_logloss: 0.513769
# [46]	train's binary_logloss: 0.48913	valid's binary_logloss: 0.511983
# [47]	train's binary_logloss: 0.486903	valid's binary_logloss: 0.510191
# [48]	train's binary_logloss: 0.484649	valid's binary_logloss: 0.508328
# [49]	train's binary_logloss: 0.482454	valid's binary_logloss: 0.506661
# [50]	train's binary_logloss: 0.480313	valid's binary_logloss: 0.504933
# [51]	train's binary_logloss: 0.478141	valid's binary_logloss: 0.50329
# [52]	train's binary_logloss: 0.47611	valid's binary_logloss: 0.501706
# [53]	train's binary_logloss: 0.474083	valid's binary_logloss: 0.500226
# [54]	train's binary_logloss: 0.47207	valid's binary_logloss: 0.498613
# [55]	train's binary_logloss: 0.470144	valid's binary_logloss: 0.497201
# [56]	train's binary_logloss: 0.468296	valid's binary_logloss: 0.495843
# [57]	train's binary_logloss: 0.46637	valid's binary_logloss: 0.494438
# [58]	train's binary_logloss: 0.464602	valid's binary_logloss: 0.493067
# [59]	train's binary_logloss: 0.462849	valid's binary_logloss: 0.491785
# [60]	train's binary_logloss: 0.461114	valid's binary_logloss: 0.490556
# [61]	train's binary_logloss: 0.459402	valid's binary_logloss: 0.489278
# [62]	train's binary_logloss: 0.457725	valid's binary_logloss: 0.48794
# [63]	train's binary_logloss: 0.456129	valid's binary_logloss: 0.48675
# [64]	train's binary_logloss: 0.454507	valid's binary_logloss: 0.485551
# [65]	train's binary_logloss: 0.452862	valid's binary_logloss: 0.484375
# [66]	train's binary_logloss: 0.451337	valid's binary_logloss: 0.4832
# [67]	train's binary_logloss: 0.449769	valid's binary_logloss: 0.482002
# [68]	train's binary_logloss: 0.448282	valid's binary_logloss: 0.480854
# [69]	train's binary_logloss: 0.446805	valid's binary_logloss: 0.479743
# [70]	train's binary_logloss: 0.445405	valid's binary_logloss: 0.478723
# [71]	train's binary_logloss: 0.443989	valid's binary_logloss: 0.477651
# [72]	train's binary_logloss: 0.442619	valid's binary_logloss: 0.476679
# [73]	train's binary_logloss: 0.441174	valid's binary_logloss: 0.475644
# [74]	train's binary_logloss: 0.439867	valid's binary_logloss: 0.474746
# [75]	train's binary_logloss: 0.438518	valid's binary_logloss: 0.4739
# [76]	train's binary_logloss: 0.437228	valid's binary_logloss: 0.473041
# [77]	train's binary_logloss: 0.43591	valid's binary_logloss: 0.472046
# [78]	train's binary_logloss: 0.434614	valid's binary_logloss: 0.471048
# [79]	train's binary_logloss: 0.433407	valid's binary_logloss: 0.470152
# [80]	train's binary_logloss: 0.43217	valid's binary_logloss: 0.469194
# [81]	train's binary_logloss: 0.431025	valid's binary_logloss: 0.468449
# [82]	train's binary_logloss: 0.429822	valid's binary_logloss: 0.467612
# [83]	train's binary_logloss: 0.428652	valid's binary_logloss: 0.466818
# [84]	train's binary_logloss: 0.427501	valid's binary_logloss: 0.466113
# [85]	train's binary_logloss: 0.426401	valid's binary_logloss: 0.465341
# [86]	train's binary_logloss: 0.425248	valid's binary_logloss: 0.464575
# [87]	train's binary_logloss: 0.424137	valid's binary_logloss: 0.463905
# [88]	train's binary_logloss: 0.423016	valid's binary_logloss: 0.463096
# [89]	train's binary_logloss: 0.421987	valid's binary_logloss: 0.462345
# [90]	train's binary_logloss: 0.420962	valid's binary_logloss: 0.461728
# [91]	train's binary_logloss: 0.419965	valid's binary_logloss: 0.461175
# [92]	train's binary_logloss: 0.418948	valid's binary_logloss: 0.460598
# [93]	train's binary_logloss: 0.417982	valid's binary_logloss: 0.460062
# [94]	train's binary_logloss: 0.416972	valid's binary_logloss: 0.459411
# [95]	train's binary_logloss: 0.415979	valid's binary_logloss: 0.458871
# [96]	train's binary_logloss: 0.415076	valid's binary_logloss: 0.458352
# [97]	train's binary_logloss: 0.414154	valid's binary_logloss: 0.457878
# [98]	train's binary_logloss: 0.413275	valid's binary_logloss: 0.457397
# [99]	train's binary_logloss: 0.412366	valid's binary_logloss: 0.456762
# [100]	train's binary_logloss: 0.41144	valid's binary_logloss: 0.456155
# 0       1
# 1       0
# 2       0
# 4       1
# 6       1
#        ..
# 9784    1
# 9787    0
# 9788    0
# 9789    1
# 9790    0
# Name: state, Length: 7833, dtype: int64
# [0 0 1 ... 0 1 1]
# [f1 score] tr:0.82, va:0.78
# -------------------- 3 --------------------
# (7833, 9) (7833,)
# (1958, 9) (1958,)
# [1]	train's binary_logloss: 0.684929	valid's binary_logloss: 0.685217
# [2]	train's binary_logloss: 0.677145	valid's binary_logloss: 0.67771
# [3]	train's binary_logloss: 0.669646	valid's binary_logloss: 0.670517
# [4]	train's binary_logloss: 0.662473	valid's binary_logloss: 0.663645
# [5]	train's binary_logloss: 0.655571	valid's binary_logloss: 0.656899
# [6]	train's binary_logloss: 0.6489	valid's binary_logloss: 0.650467
# [7]	train's binary_logloss: 0.64242	valid's binary_logloss: 0.644222
# [8]	train's binary_logloss: 0.636148	valid's binary_logloss: 0.63809
# [9]	train's binary_logloss: 0.630136	valid's binary_logloss: 0.632328
# [10]	train's binary_logloss: 0.624253	valid's binary_logloss: 0.626557
# [11]	train's binary_logloss: 0.61858	valid's binary_logloss: 0.621112
# [12]	train's binary_logloss: 0.613144	valid's binary_logloss: 0.615937
# [13]	train's binary_logloss: 0.60784	valid's binary_logloss: 0.610883
# [14]	train's binary_logloss: 0.602752	valid's binary_logloss: 0.60599
# [15]	train's binary_logloss: 0.59775	valid's binary_logloss: 0.601184
# [16]	train's binary_logloss: 0.592788	valid's binary_logloss: 0.596447
# [17]	train's binary_logloss: 0.58806	valid's binary_logloss: 0.591921
# [18]	train's binary_logloss: 0.58334	valid's binary_logloss: 0.58748
# [19]	train's binary_logloss: 0.578874	valid's binary_logloss: 0.583349
# [20]	train's binary_logloss: 0.57456	valid's binary_logloss: 0.579196
# [21]	train's binary_logloss: 0.570282	valid's binary_logloss: 0.575119
# [22]	train's binary_logloss: 0.566215	valid's binary_logloss: 0.571356
# [23]	train's binary_logloss: 0.562189	valid's binary_logloss: 0.567513
# [24]	train's binary_logloss: 0.558337	valid's binary_logloss: 0.563929
# [25]	train's binary_logloss: 0.554506	valid's binary_logloss: 0.560246
# [26]	train's binary_logloss: 0.5508	valid's binary_logloss: 0.556778
# [27]	train's binary_logloss: 0.547277	valid's binary_logloss: 0.553537
# [28]	train's binary_logloss: 0.543747	valid's binary_logloss: 0.550215
# [29]	train's binary_logloss: 0.540312	valid's binary_logloss: 0.547017
# [30]	train's binary_logloss: 0.536906	valid's binary_logloss: 0.543905
# [31]	train's binary_logloss: 0.533686	valid's binary_logloss: 0.540846
# [32]	train's binary_logloss: 0.530404	valid's binary_logloss: 0.537737
# [33]	train's binary_logloss: 0.527356	valid's binary_logloss: 0.534938
# [34]	train's binary_logloss: 0.52431	valid's binary_logloss: 0.532131
# [35]	train's binary_logloss: 0.521324	valid's binary_logloss: 0.529321
# [36]	train's binary_logloss: 0.51848	valid's binary_logloss: 0.526816
# [37]	train's binary_logloss: 0.515597	valid's binary_logloss: 0.524222
# [38]	train's binary_logloss: 0.512758	valid's binary_logloss: 0.52169
# [39]	train's binary_logloss: 0.51005	valid's binary_logloss: 0.519287
# [40]	train's binary_logloss: 0.507387	valid's binary_logloss: 0.516907
# [41]	train's binary_logloss: 0.504809	valid's binary_logloss: 0.514654
# [42]	train's binary_logloss: 0.502241	valid's binary_logloss: 0.512369
# [43]	train's binary_logloss: 0.49972	valid's binary_logloss: 0.510108
# [44]	train's binary_logloss: 0.497239	valid's binary_logloss: 0.507892
# [45]	train's binary_logloss: 0.494857	valid's binary_logloss: 0.505809
# [46]	train's binary_logloss: 0.492528	valid's binary_logloss: 0.503655
# [47]	train's binary_logloss: 0.490238	valid's binary_logloss: 0.5016
# [48]	train's binary_logloss: 0.488018	valid's binary_logloss: 0.499615
# [49]	train's binary_logloss: 0.485855	valid's binary_logloss: 0.497721
# [50]	train's binary_logloss: 0.483711	valid's binary_logloss: 0.495947
# [51]	train's binary_logloss: 0.481651	valid's binary_logloss: 0.49422
# [52]	train's binary_logloss: 0.47956	valid's binary_logloss: 0.492437
# [53]	train's binary_logloss: 0.477555	valid's binary_logloss: 0.490623
# [54]	train's binary_logloss: 0.475671	valid's binary_logloss: 0.488919
# [55]	train's binary_logloss: 0.473794	valid's binary_logloss: 0.487209
# [56]	train's binary_logloss: 0.471931	valid's binary_logloss: 0.485643
# [57]	train's binary_logloss: 0.470063	valid's binary_logloss: 0.484112
# [58]	train's binary_logloss: 0.46828	valid's binary_logloss: 0.48258
# [59]	train's binary_logloss: 0.466538	valid's binary_logloss: 0.481063
# [60]	train's binary_logloss: 0.464814	valid's binary_logloss: 0.479563
# [61]	train's binary_logloss: 0.463175	valid's binary_logloss: 0.478103
# [62]	train's binary_logloss: 0.461547	valid's binary_logloss: 0.476748
# [63]	train's binary_logloss: 0.459958	valid's binary_logloss: 0.47533
# [64]	train's binary_logloss: 0.458398	valid's binary_logloss: 0.47386
# [65]	train's binary_logloss: 0.456876	valid's binary_logloss: 0.472499
# [66]	train's binary_logloss: 0.455409	valid's binary_logloss: 0.471191
# [67]	train's binary_logloss: 0.45388	valid's binary_logloss: 0.469849
# [68]	train's binary_logloss: 0.452462	valid's binary_logloss: 0.468743
# [69]	train's binary_logloss: 0.45099	valid's binary_logloss: 0.467476
# [70]	train's binary_logloss: 0.449526	valid's binary_logloss: 0.466238
# [71]	train's binary_logloss: 0.448134	valid's binary_logloss: 0.465141
# [72]	train's binary_logloss: 0.446754	valid's binary_logloss: 0.463982
# [73]	train's binary_logloss: 0.445407	valid's binary_logloss: 0.462958
# [74]	train's binary_logloss: 0.443991	valid's binary_logloss: 0.461798
# [75]	train's binary_logloss: 0.442736	valid's binary_logloss: 0.460719
# [76]	train's binary_logloss: 0.441431	valid's binary_logloss: 0.459599
# [77]	train's binary_logloss: 0.440108	valid's binary_logloss: 0.458562
# [78]	train's binary_logloss: 0.438836	valid's binary_logloss: 0.4576
# [79]	train's binary_logloss: 0.437624	valid's binary_logloss: 0.456604
# [80]	train's binary_logloss: 0.436379	valid's binary_logloss: 0.455607
# [81]	train's binary_logloss: 0.435176	valid's binary_logloss: 0.454648
# [82]	train's binary_logloss: 0.434021	valid's binary_logloss: 0.453821
# [83]	train's binary_logloss: 0.432871	valid's binary_logloss: 0.452957
# [84]	train's binary_logloss: 0.431729	valid's binary_logloss: 0.452077
# [85]	train's binary_logloss: 0.430656	valid's binary_logloss: 0.451319
# [86]	train's binary_logloss: 0.429556	valid's binary_logloss: 0.450536
# [87]	train's binary_logloss: 0.428401	valid's binary_logloss: 0.449696
# [88]	train's binary_logloss: 0.427355	valid's binary_logloss: 0.448934
# [89]	train's binary_logloss: 0.426311	valid's binary_logloss: 0.44806
# [90]	train's binary_logloss: 0.425322	valid's binary_logloss: 0.447353
# [91]	train's binary_logloss: 0.424317	valid's binary_logloss: 0.44651
# [92]	train's binary_logloss: 0.423305	valid's binary_logloss: 0.445828
# [93]	train's binary_logloss: 0.422339	valid's binary_logloss: 0.44518
# [94]	train's binary_logloss: 0.421421	valid's binary_logloss: 0.444522
# [95]	train's binary_logloss: 0.420423	valid's binary_logloss: 0.443839
# [96]	train's binary_logloss: 0.41952	valid's binary_logloss: 0.44306
# [97]	train's binary_logloss: 0.418611	valid's binary_logloss: 0.442339
# [98]	train's binary_logloss: 0.417724	valid's binary_logloss: 0.441618
# [99]	train's binary_logloss: 0.416839	valid's binary_logloss: 0.441012
# [100]	train's binary_logloss: 0.415994	valid's binary_logloss: 0.440345
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 9785    0
# 9786    0
# 9787    0
# 9788    0
# 9790    0
# Name: state, Length: 7833, dtype: int64
# [0 0 1 ... 0 0 1]
# [f1 score] tr:0.81, va:0.78
# -------------------- 4 --------------------
# (7833, 9) (7833,)
# (1958, 9) (1958,)
# [1]	train's binary_logloss: 0.684968	valid's binary_logloss: 0.685365
# [2]	train's binary_logloss: 0.677197	valid's binary_logloss: 0.677982
# [3]	train's binary_logloss: 0.669754	valid's binary_logloss: 0.670863
# [4]	train's binary_logloss: 0.662591	valid's binary_logloss: 0.664046
# [5]	train's binary_logloss: 0.65557	valid's binary_logloss: 0.657424
# [6]	train's binary_logloss: 0.648902	valid's binary_logloss: 0.651064
# [7]	train's binary_logloss: 0.642378	valid's binary_logloss: 0.644968
# [8]	train's binary_logloss: 0.636117	valid's binary_logloss: 0.639113
# [9]	train's binary_logloss: 0.630017	valid's binary_logloss: 0.633259
# [10]	train's binary_logloss: 0.624043	valid's binary_logloss: 0.627573
# [11]	train's binary_logloss: 0.618439	valid's binary_logloss: 0.62223
# [12]	train's binary_logloss: 0.612801	valid's binary_logloss: 0.616873
# [13]	train's binary_logloss: 0.607427	valid's binary_logloss: 0.611827
# [14]	train's binary_logloss: 0.60212	valid's binary_logloss: 0.606899
# [15]	train's binary_logloss: 0.596935	valid's binary_logloss: 0.602003
# [16]	train's binary_logloss: 0.59203	valid's binary_logloss: 0.59734
# [17]	train's binary_logloss: 0.587217	valid's binary_logloss: 0.592759
# [18]	train's binary_logloss: 0.582448	valid's binary_logloss: 0.588306
# [19]	train's binary_logloss: 0.577938	valid's binary_logloss: 0.584086
# [20]	train's binary_logloss: 0.573554	valid's binary_logloss: 0.579985
# [21]	train's binary_logloss: 0.569299	valid's binary_logloss: 0.575954
# [22]	train's binary_logloss: 0.565098	valid's binary_logloss: 0.572083
# [23]	train's binary_logloss: 0.561069	valid's binary_logloss: 0.568256
# [24]	train's binary_logloss: 0.557155	valid's binary_logloss: 0.564705
# [25]	train's binary_logloss: 0.553394	valid's binary_logloss: 0.56127
# [26]	train's binary_logloss: 0.549658	valid's binary_logloss: 0.557905
# [27]	train's binary_logloss: 0.546044	valid's binary_logloss: 0.554628
# [28]	train's binary_logloss: 0.542514	valid's binary_logloss: 0.551482
# [29]	train's binary_logloss: 0.539088	valid's binary_logloss: 0.548312
# [30]	train's binary_logloss: 0.535685	valid's binary_logloss: 0.545065
# [31]	train's binary_logloss: 0.532354	valid's binary_logloss: 0.541941
# [32]	train's binary_logloss: 0.529042	valid's binary_logloss: 0.538898
# [33]	train's binary_logloss: 0.525872	valid's binary_logloss: 0.535931
# [34]	train's binary_logloss: 0.522781	valid's binary_logloss: 0.533021
# [35]	train's binary_logloss: 0.51976	valid's binary_logloss: 0.530206
# [36]	train's binary_logloss: 0.516969	valid's binary_logloss: 0.527777
# [37]	train's binary_logloss: 0.514078	valid's binary_logloss: 0.525068
# [38]	train's binary_logloss: 0.511362	valid's binary_logloss: 0.522496
# [39]	train's binary_logloss: 0.508735	valid's binary_logloss: 0.520102
# [40]	train's binary_logloss: 0.506135	valid's binary_logloss: 0.517711
# [41]	train's binary_logloss: 0.503663	valid's binary_logloss: 0.515398
# [42]	train's binary_logloss: 0.501148	valid's binary_logloss: 0.513073
# [43]	train's binary_logloss: 0.498734	valid's binary_logloss: 0.510881
# [44]	train's binary_logloss: 0.496344	valid's binary_logloss: 0.508693
# [45]	train's binary_logloss: 0.493967	valid's binary_logloss: 0.506634
# [46]	train's binary_logloss: 0.491674	valid's binary_logloss: 0.504567
# [47]	train's binary_logloss: 0.489402	valid's binary_logloss: 0.502409
# [48]	train's binary_logloss: 0.48723	valid's binary_logloss: 0.500645
# [49]	train's binary_logloss: 0.485127	valid's binary_logloss: 0.498879
# [50]	train's binary_logloss: 0.483016	valid's binary_logloss: 0.497104
# [51]	train's binary_logloss: 0.480945	valid's binary_logloss: 0.495072
# [52]	train's binary_logloss: 0.478992	valid's binary_logloss: 0.493346
# [53]	train's binary_logloss: 0.477014	valid's binary_logloss: 0.491527
# [54]	train's binary_logloss: 0.475044	valid's binary_logloss: 0.489849
# [55]	train's binary_logloss: 0.473167	valid's binary_logloss: 0.488191
# [56]	train's binary_logloss: 0.471235	valid's binary_logloss: 0.486431
# [57]	train's binary_logloss: 0.469348	valid's binary_logloss: 0.484708
# [58]	train's binary_logloss: 0.467552	valid's binary_logloss: 0.483101
# [59]	train's binary_logloss: 0.465804	valid's binary_logloss: 0.481556
# [60]	train's binary_logloss: 0.464079	valid's binary_logloss: 0.480125
# [61]	train's binary_logloss: 0.462453	valid's binary_logloss: 0.47864
# [62]	train's binary_logloss: 0.460826	valid's binary_logloss: 0.477243
# [63]	train's binary_logloss: 0.459128	valid's binary_logloss: 0.475742
# [64]	train's binary_logloss: 0.457553	valid's binary_logloss: 0.474305
# [65]	train's binary_logloss: 0.455962	valid's binary_logloss: 0.472915
# [66]	train's binary_logloss: 0.454363	valid's binary_logloss: 0.471445
# [67]	train's binary_logloss: 0.452829	valid's binary_logloss: 0.47008
# [68]	train's binary_logloss: 0.451366	valid's binary_logloss: 0.468737
# [69]	train's binary_logloss: 0.449943	valid's binary_logloss: 0.467433
# [70]	train's binary_logloss: 0.448458	valid's binary_logloss: 0.466139
# [71]	train's binary_logloss: 0.447039	valid's binary_logloss: 0.464931
# [72]	train's binary_logloss: 0.445648	valid's binary_logloss: 0.463755
# [73]	train's binary_logloss: 0.444311	valid's binary_logloss: 0.462712
# [74]	train's binary_logloss: 0.442961	valid's binary_logloss: 0.461562
# [75]	train's binary_logloss: 0.441624	valid's binary_logloss: 0.46048
# [76]	train's binary_logloss: 0.440305	valid's binary_logloss: 0.459344
# [77]	train's binary_logloss: 0.439055	valid's binary_logloss: 0.458228
# [78]	train's binary_logloss: 0.437854	valid's binary_logloss: 0.457154
# [79]	train's binary_logloss: 0.436607	valid's binary_logloss: 0.456079
# [80]	train's binary_logloss: 0.435388	valid's binary_logloss: 0.455212
# [81]	train's binary_logloss: 0.43419	valid's binary_logloss: 0.454187
# [82]	train's binary_logloss: 0.433038	valid's binary_logloss: 0.453177
# [83]	train's binary_logloss: 0.431894	valid's binary_logloss: 0.452206
# [84]	train's binary_logloss: 0.430781	valid's binary_logloss: 0.45131
# [85]	train's binary_logloss: 0.429664	valid's binary_logloss: 0.450412
# [86]	train's binary_logloss: 0.428567	valid's binary_logloss: 0.449501
# [87]	train's binary_logloss: 0.427482	valid's binary_logloss: 0.448647
# [88]	train's binary_logloss: 0.426432	valid's binary_logloss: 0.447808
# [89]	train's binary_logloss: 0.425415	valid's binary_logloss: 0.446947
# [90]	train's binary_logloss: 0.424411	valid's binary_logloss: 0.44613
# [91]	train's binary_logloss: 0.423404	valid's binary_logloss: 0.445409
# [92]	train's binary_logloss: 0.422435	valid's binary_logloss: 0.444616
# [93]	train's binary_logloss: 0.421446	valid's binary_logloss: 0.44393
# [94]	train's binary_logloss: 0.420504	valid's binary_logloss: 0.443113
# [95]	train's binary_logloss: 0.419572	valid's binary_logloss: 0.442447
# [96]	train's binary_logloss: 0.418636	valid's binary_logloss: 0.441765
# [97]	train's binary_logloss: 0.417647	valid's binary_logloss: 0.441056
# [98]	train's binary_logloss: 0.416786	valid's binary_logloss: 0.440282
# [99]	train's binary_logloss: 0.415903	valid's binary_logloss: 0.439693
# [100]	train's binary_logloss: 0.415012	valid's binary_logloss: 0.439013
# 0       1
# 1       0
# 2       0
# 3       1
# 5       0
#        ..
# 9785    0
# 9786    0
# 9787    0
# 9789    1
# 9790    0
# Name: state, Length: 7833, dtype: int64
# [0 0 1 ... 0 1 1]
# [f1 score] tr:0.81, va:0.79
# ==================== result ====================
# [[0.         0.81758357 0.77585302]
#  [1.         0.81321004 0.7805394 ]
#  [2.         0.81675254 0.77566138]
#  [3.         0.81363934 0.78366914]
#  [4.         0.81327691 0.78697277]]

# %%
sub = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/sample_submit.csv', header=None)
sub
# Out:
#                0  1
# 0     test_00000  1
# 1     test_00001  0
# 2     test_00002  0
# 3     test_00003  0
# 4     test_00004  1
# ...          ... ..
# 9795  test_09795  0
# 9796  test_09796  0
# 9797  test_09797  1
# 9798  test_09798  0
# 9799  test_09799  0
#
# [9800 rows x 2 columns]

# %%
# df_text = test[['html_content']]
# df_text['html_content'] = cleaning(df_text['html_content'])
# print(df_text.shape)

# vec = CountVectorizer(min_df=200)

# vec.fit(df_text['html_content'])

# html_content_test = pd.DataFrame(vec.transform(df_text['html_content']).toarray(), columns=vec.get_feature_names())
# print(html_content_test.shape)
# html_content_test

# %%
fold_test = pd.DataFrame(np.load("/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Oututput/test-2-bert-deberta-base-epoch10/preds/sub_pred.npy"))
print(fold_test.shape)
fold_test
# Out:
# (9800, 4)
#              0         1         2         3
# 0     0.400787  0.598572  0.000198  0.000212
# 1     0.074722  0.924805  0.000158  0.000124
# 2     0.046900  0.952881  0.000107  0.000120
# 3     0.934082  0.065323  0.000211  0.000178
# 4     0.948242  0.051544  0.000181  0.000152
# ...        ...       ...       ...       ...
# 9795  0.276001  0.723633  0.000206  0.000203
# 9796  0.151062  0.848389  0.000207  0.000192
# 9797  0.729980  0.269501  0.000313  0.000279
# 9798  0.472534  0.526733  0.000289  0.000384
# 9799  0.027340  0.972656  0.000134  0.000156
#
# [9800 rows x 4 columns]

# %%
x_test = test[['goal', 'country', 'duration', 'category1', 'category2']]
x_test.columns = ['goal1', 'country1', 'duration1', 'category1', 'category2']
id_test = test['id']

for column in categorical_features:
  target_column = x_test[column]
  le = LabelEncoder()
  le.fit(target_column)
  label_encoded_column = le.transform(target_column)
  x_test[column] = pd.Series(label_encoded_column).astype('category')

# print(x_test.shape)
# x_test = pd.concat([x_test, html_content_test], axis=1)
print(x_test.shape)
x_test = pd.concat([x_test, fold_test], axis=1)
print(x_test.shape)

y_test_pred = model.predict(x_test)
y_test_pred = np.where(y_test_pred > 0.5, 1, 0)
print(id_test)
print(y_test_pred)
df_submit = pd.DataFrame({'id':id_test, 'pred':y_test_pred})
print(df_submit)
df_submit.to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/submit_4.csv', index=None, header=None)
# Out:
# (9800, 5)
# (9800, 9)
# 0       test_00000
# 1       test_00001
# 2       test_00002
# 3       test_00003
# 4       test_00004
#            ...
# 9795    test_09795
# 9796    test_09796
# 9797    test_09797
# 9798    test_09798
# 9799    test_09799
# Name: id, Length: 9800, dtype: object
# [1 1 1 ... 0 1 1]
#               id  pred
# 0     test_00000     1
# 1     test_00001     1
# 2     test_00002     1
# 3     test_00003     0
# 4     test_00004     0
# ...          ...   ...
# 9795  test_09795     0
# 9796  test_09796     1
# 9797  test_09797     0
# 9798  test_09798     1
# 9799  test_09799     1
#
# [9800 rows x 2 columns]
