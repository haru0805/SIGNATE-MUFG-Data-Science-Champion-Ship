# %%
import numpy as np
import pandas as pd
import os
import pickle
import gc

import pandas_profiling as pdp

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
import lightgbm as lgb

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/train.csv')
test = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/test.csv')
sub = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/sample_submit.csv')

# %%
class cfg:
  n_splits = 5

  seed = 123

  num_round = 100

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'learning_rate': 0.1,
    'num_leaves': 16,
    'm_estimators': 100000,
    'random_state': cfg.seed,
    'importance_type': 'gain',
}

# %%
x_train = train[['goal', 'country', 'duration', 'category1', 'category2']]
# x_train = train[['duration']]
y_train = train['state']
id_train = train['id']
categorical_features = ['goal', 'country', 'category1', 'category2']

cv = list(StratifiedKFold(n_splits=cfg.n_splits, shuffle=True, random_state=cfg.seed).split(x_train, y_train))

metrics = []
imp = pd.DataFrame()

for column in categorical_features:
  target_column = x_train[column]
  le = LabelEncoder()
  le.fit(target_column)
  label_encoded_column = le.transform(target_column)
  x_train[column] = pd.Series(label_encoded_column).astype('category')

for nfold in range(cfg.n_splits):
  print('-'*20, nfold, '-'*20)
  idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
  x_tr, y_tr = x_train.loc[idx_tr], y_train.loc[idx_tr]
  x_va, y_va = x_train.loc[idx_va], y_train.loc[idx_va]
  print(x_tr.shape, y_tr.shape)
  print(x_va.shape, y_va.shape)

  lgb_tr = lgb.Dataset(x_tr, y_tr)
  lgb_va = lgb.Dataset(x_va, y_va)

  lgb_results = {}
  model = lgb.train(params, lgb_tr, num_boost_round=cfg.num_round,
                    valid_names=['train', 'valid'],
                    valid_sets=[lgb_tr, lgb_va])   

  y_tr_pred = model.predict(x_tr)
  y_va_pred = model.predict(x_va)
  y_tr_pred = np.where(y_tr_pred > 0.5, 1, 0)
  y_va_pred = np.where(y_va_pred > 0.5, 1, 0)
  print(y_tr)
  print(y_tr_pred)
  f1_tr = f1_score(y_tr, y_tr_pred)
  f1_va = f1_score(y_va, y_va_pred)
  print('[f1 score] tr:{:.2f}, va:{:.2f}'.format(f1_tr, f1_va))
  metrics.append([nfold, f1_tr, f1_va])


  # _imp = pd.DataFrame({'col':x_train.columns, 'imp':model.feature_importances_, 'nfold':nfold})
  # imp = pd.concat([imp, _imp], axis=0, ignore_index=True)

print('='*20, 'result', '='*20)
metrics = np.array(metrics)
print(metrics)
# Out:
# -------------------- 0 --------------------
# (7832, 5) (7832,)
# (1959, 5) (1959,)
# [1]	train's binary_logloss: 0.661627	valid's binary_logloss: 0.662542
# [2]	train's binary_logloss: 0.63548	valid's binary_logloss: 0.637984
# [3]	train's binary_logloss: 0.613162	valid's binary_logloss: 0.616619
# [4]	train's binary_logloss: 0.593663	valid's binary_logloss: 0.598985
# [5]	train's binary_logloss: 0.577127	valid's binary_logloss: 0.583821
# [6]	train's binary_logloss: 0.562677	valid's binary_logloss: 0.570152
# [7]	train's binary_logloss: 0.549847	valid's binary_logloss: 0.558687
# [8]	train's binary_logloss: 0.538632	valid's binary_logloss: 0.549084
# [9]	train's binary_logloss: 0.528585	valid's binary_logloss: 0.540962
# [10]	train's binary_logloss: 0.519945	valid's binary_logloss: 0.533629
# [11]	train's binary_logloss: 0.512085	valid's binary_logloss: 0.526808
# [12]	train's binary_logloss: 0.505135	valid's binary_logloss: 0.521006
# [13]	train's binary_logloss: 0.499115	valid's binary_logloss: 0.516195
# [14]	train's binary_logloss: 0.493207	valid's binary_logloss: 0.512322
# [15]	train's binary_logloss: 0.487984	valid's binary_logloss: 0.508185
# [16]	train's binary_logloss: 0.483533	valid's binary_logloss: 0.504517
# [17]	train's binary_logloss: 0.479211	valid's binary_logloss: 0.501312
# [18]	train's binary_logloss: 0.475282	valid's binary_logloss: 0.498752
# [19]	train's binary_logloss: 0.471499	valid's binary_logloss: 0.496494
# [20]	train's binary_logloss: 0.467854	valid's binary_logloss: 0.49462
# [21]	train's binary_logloss: 0.464695	valid's binary_logloss: 0.4927
# [22]	train's binary_logloss: 0.461784	valid's binary_logloss: 0.491301
# [23]	train's binary_logloss: 0.458932	valid's binary_logloss: 0.489821
# [24]	train's binary_logloss: 0.456385	valid's binary_logloss: 0.488639
# [25]	train's binary_logloss: 0.453972	valid's binary_logloss: 0.487629
# [26]	train's binary_logloss: 0.451635	valid's binary_logloss: 0.486751
# [27]	train's binary_logloss: 0.449479	valid's binary_logloss: 0.485679
# [28]	train's binary_logloss: 0.447349	valid's binary_logloss: 0.484692
# [29]	train's binary_logloss: 0.445055	valid's binary_logloss: 0.483628
# [30]	train's binary_logloss: 0.443012	valid's binary_logloss: 0.482652
# [31]	train's binary_logloss: 0.440873	valid's binary_logloss: 0.481418
# [32]	train's binary_logloss: 0.43922	valid's binary_logloss: 0.480567
# [33]	train's binary_logloss: 0.437476	valid's binary_logloss: 0.480024
# [34]	train's binary_logloss: 0.436108	valid's binary_logloss: 0.479886
# [35]	train's binary_logloss: 0.434545	valid's binary_logloss: 0.479806
# [36]	train's binary_logloss: 0.433137	valid's binary_logloss: 0.479761
# [37]	train's binary_logloss: 0.432067	valid's binary_logloss: 0.479626
# [38]	train's binary_logloss: 0.430751	valid's binary_logloss: 0.479762
# [39]	train's binary_logloss: 0.429404	valid's binary_logloss: 0.479789
# [40]	train's binary_logloss: 0.428281	valid's binary_logloss: 0.479708
# [41]	train's binary_logloss: 0.427072	valid's binary_logloss: 0.479215
# [42]	train's binary_logloss: 0.425852	valid's binary_logloss: 0.479182
# [43]	train's binary_logloss: 0.424547	valid's binary_logloss: 0.479033
# [44]	train's binary_logloss: 0.423429	valid's binary_logloss: 0.478701
# [45]	train's binary_logloss: 0.42222	valid's binary_logloss: 0.478126
# [46]	train's binary_logloss: 0.4213	valid's binary_logloss: 0.478032
# [47]	train's binary_logloss: 0.420511	valid's binary_logloss: 0.477865
# [48]	train's binary_logloss: 0.419687	valid's binary_logloss: 0.477747
# [49]	train's binary_logloss: 0.418579	valid's binary_logloss: 0.477527
# [50]	train's binary_logloss: 0.417425	valid's binary_logloss: 0.47752
# [51]	train's binary_logloss: 0.416511	valid's binary_logloss: 0.477433
# [52]	train's binary_logloss: 0.415571	valid's binary_logloss: 0.477522
# [53]	train's binary_logloss: 0.414535	valid's binary_logloss: 0.477248
# [54]	train's binary_logloss: 0.413545	valid's binary_logloss: 0.476977
# [55]	train's binary_logloss: 0.412492	valid's binary_logloss: 0.477226
# [56]	train's binary_logloss: 0.411674	valid's binary_logloss: 0.477697
# [57]	train's binary_logloss: 0.41032	valid's binary_logloss: 0.477699
# [58]	train's binary_logloss: 0.40942	valid's binary_logloss: 0.4778
# [59]	train's binary_logloss: 0.408321	valid's binary_logloss: 0.47816
# [60]	train's binary_logloss: 0.407298	valid's binary_logloss: 0.478279
# [61]	train's binary_logloss: 0.406698	valid's binary_logloss: 0.478464
# [62]	train's binary_logloss: 0.405763	valid's binary_logloss: 0.479035
# [63]	train's binary_logloss: 0.404731	valid's binary_logloss: 0.479198
# [64]	train's binary_logloss: 0.403863	valid's binary_logloss: 0.479147
# [65]	train's binary_logloss: 0.40262	valid's binary_logloss: 0.479279
# [66]	train's binary_logloss: 0.401997	valid's binary_logloss: 0.478783
# [67]	train's binary_logloss: 0.401308	valid's binary_logloss: 0.478681
# [68]	train's binary_logloss: 0.400218	valid's binary_logloss: 0.478623
# [69]	train's binary_logloss: 0.399177	valid's binary_logloss: 0.478804
# [70]	train's binary_logloss: 0.398292	valid's binary_logloss: 0.4792
# [71]	train's binary_logloss: 0.397535	valid's binary_logloss: 0.479457
# [72]	train's binary_logloss: 0.396744	valid's binary_logloss: 0.479192
# [73]	train's binary_logloss: 0.395993	valid's binary_logloss: 0.47927
# [74]	train's binary_logloss: 0.395116	valid's binary_logloss: 0.479577
# [75]	train's binary_logloss: 0.394586	valid's binary_logloss: 0.479629
# [76]	train's binary_logloss: 0.393797	valid's binary_logloss: 0.479677
# [77]	train's binary_logloss: 0.393103	valid's binary_logloss: 0.480028
# [78]	train's binary_logloss: 0.392362	valid's binary_logloss: 0.48003
# [79]	train's binary_logloss: 0.391344	valid's binary_logloss: 0.480207
# [80]	train's binary_logloss: 0.390465	valid's binary_logloss: 0.480539
# [81]	train's binary_logloss: 0.389657	valid's binary_logloss: 0.480431
# [82]	train's binary_logloss: 0.388915	valid's binary_logloss: 0.480476
# [83]	train's binary_logloss: 0.388163	valid's binary_logloss: 0.480702
# [84]	train's binary_logloss: 0.387491	valid's binary_logloss: 0.480886
# [85]	train's binary_logloss: 0.386827	valid's binary_logloss: 0.481034
# [86]	train's binary_logloss: 0.385937	valid's binary_logloss: 0.481391
# [87]	train's binary_logloss: 0.385423	valid's binary_logloss: 0.481461
# [88]	train's binary_logloss: 0.384717	valid's binary_logloss: 0.481601
# [89]	train's binary_logloss: 0.384066	valid's binary_logloss: 0.481981
# [90]	train's binary_logloss: 0.383646	valid's binary_logloss: 0.482011
# [91]	train's binary_logloss: 0.382882	valid's binary_logloss: 0.482393
# [92]	train's binary_logloss: 0.382223	valid's binary_logloss: 0.482779
# [93]	train's binary_logloss: 0.381804	valid's binary_logloss: 0.482845
# [94]	train's binary_logloss: 0.380963	valid's binary_logloss: 0.48336
# [95]	train's binary_logloss: 0.380259	valid's binary_logloss: 0.483534
# [96]	train's binary_logloss: 0.379359	valid's binary_logloss: 0.483996
# [97]	train's binary_logloss: 0.378632	valid's binary_logloss: 0.483937
# [98]	train's binary_logloss: 0.377902	valid's binary_logloss: 0.483945
# [99]	train's binary_logloss: 0.377312	valid's binary_logloss: 0.484111
# [100]	train's binary_logloss: 0.376447	valid's binary_logloss: 0.484365
# 0       1
# 2       0
# 3       1
# 4       1
# 5       0
#        ..
# 9785    0
# 9786    0
# 9788    0
# 9789    1
# 9790    0
# Name: state, Length: 7832, dtype: int64
# [0 0 0 ... 0 1 0]
# [f1 score] tr:0.81, va:0.73
# -------------------- 1 --------------------
# (7833, 5) (7833,)
# (1958, 5) (1958,)
# [1]	train's binary_logloss: 0.66143	valid's binary_logloss: 0.66198
# [2]	train's binary_logloss: 0.63551	valid's binary_logloss: 0.637211
# [3]	train's binary_logloss: 0.613547	valid's binary_logloss: 0.616813
# [4]	train's binary_logloss: 0.594364	valid's binary_logloss: 0.59883
# [5]	train's binary_logloss: 0.577956	valid's binary_logloss: 0.584093
# [6]	train's binary_logloss: 0.563718	valid's binary_logloss: 0.570608
# [7]	train's binary_logloss: 0.551168	valid's binary_logloss: 0.559301
# [8]	train's binary_logloss: 0.54009	valid's binary_logloss: 0.549727
# [9]	train's binary_logloss: 0.530297	valid's binary_logloss: 0.541414
# [10]	train's binary_logloss: 0.521577	valid's binary_logloss: 0.533816
# [11]	train's binary_logloss: 0.513907	valid's binary_logloss: 0.52712
# [12]	train's binary_logloss: 0.507166	valid's binary_logloss: 0.52181
# [13]	train's binary_logloss: 0.501002	valid's binary_logloss: 0.516892
# [14]	train's binary_logloss: 0.495424	valid's binary_logloss: 0.512658
# [15]	train's binary_logloss: 0.490528	valid's binary_logloss: 0.508908
# [16]	train's binary_logloss: 0.485865	valid's binary_logloss: 0.505561
# [17]	train's binary_logloss: 0.48141	valid's binary_logloss: 0.502288
# [18]	train's binary_logloss: 0.477352	valid's binary_logloss: 0.499524
# [19]	train's binary_logloss: 0.473814	valid's binary_logloss: 0.497064
# [20]	train's binary_logloss: 0.470287	valid's binary_logloss: 0.495092
# [21]	train's binary_logloss: 0.467117	valid's binary_logloss: 0.492697
# [22]	train's binary_logloss: 0.464077	valid's binary_logloss: 0.490801
# [23]	train's binary_logloss: 0.461054	valid's binary_logloss: 0.489581
# [24]	train's binary_logloss: 0.458265	valid's binary_logloss: 0.488376
# [25]	train's binary_logloss: 0.455823	valid's binary_logloss: 0.487063
# [26]	train's binary_logloss: 0.453201	valid's binary_logloss: 0.486204
# [27]	train's binary_logloss: 0.450938	valid's binary_logloss: 0.484672
# [28]	train's binary_logloss: 0.44852	valid's binary_logloss: 0.483778
# [29]	train's binary_logloss: 0.446699	valid's binary_logloss: 0.482907
# [30]	train's binary_logloss: 0.444548	valid's binary_logloss: 0.482418
# [31]	train's binary_logloss: 0.442985	valid's binary_logloss: 0.481666
# [32]	train's binary_logloss: 0.441394	valid's binary_logloss: 0.481009
# [33]	train's binary_logloss: 0.439761	valid's binary_logloss: 0.480766
# [34]	train's binary_logloss: 0.438361	valid's binary_logloss: 0.480009
# [35]	train's binary_logloss: 0.436789	valid's binary_logloss: 0.479138
# [36]	train's binary_logloss: 0.435534	valid's binary_logloss: 0.479026
# [37]	train's binary_logloss: 0.434264	valid's binary_logloss: 0.479049
# [38]	train's binary_logloss: 0.432758	valid's binary_logloss: 0.47882
# [39]	train's binary_logloss: 0.43132	valid's binary_logloss: 0.47876
# [40]	train's binary_logloss: 0.430136	valid's binary_logloss: 0.47858
# [41]	train's binary_logloss: 0.428922	valid's binary_logloss: 0.478158
# [42]	train's binary_logloss: 0.427821	valid's binary_logloss: 0.47759
# [43]	train's binary_logloss: 0.426747	valid's binary_logloss: 0.477736
# [44]	train's binary_logloss: 0.425637	valid's binary_logloss: 0.477429
# [45]	train's binary_logloss: 0.424576	valid's binary_logloss: 0.477625
# [46]	train's binary_logloss: 0.423277	valid's binary_logloss: 0.477266
# [47]	train's binary_logloss: 0.422344	valid's binary_logloss: 0.47712
# [48]	train's binary_logloss: 0.421557	valid's binary_logloss: 0.477219
# [49]	train's binary_logloss: 0.420568	valid's binary_logloss: 0.476784
# [50]	train's binary_logloss: 0.41932	valid's binary_logloss: 0.476813
# [51]	train's binary_logloss: 0.418418	valid's binary_logloss: 0.476861
# [52]	train's binary_logloss: 0.417587	valid's binary_logloss: 0.477075
# [53]	train's binary_logloss: 0.416645	valid's binary_logloss: 0.477047
# [54]	train's binary_logloss: 0.415809	valid's binary_logloss: 0.4772
# [55]	train's binary_logloss: 0.414783	valid's binary_logloss: 0.477432
# [56]	train's binary_logloss: 0.413939	valid's binary_logloss: 0.477563
# [57]	train's binary_logloss: 0.412924	valid's binary_logloss: 0.477557
# [58]	train's binary_logloss: 0.411881	valid's binary_logloss: 0.477916
# [59]	train's binary_logloss: 0.410889	valid's binary_logloss: 0.477993
# [60]	train's binary_logloss: 0.409949	valid's binary_logloss: 0.478313
# [61]	train's binary_logloss: 0.409096	valid's binary_logloss: 0.478251
# [62]	train's binary_logloss: 0.408235	valid's binary_logloss: 0.478185
# [63]	train's binary_logloss: 0.407486	valid's binary_logloss: 0.478123
# [64]	train's binary_logloss: 0.406172	valid's binary_logloss: 0.478209
# [65]	train's binary_logloss: 0.405231	valid's binary_logloss: 0.478533
# [66]	train's binary_logloss: 0.404433	valid's binary_logloss: 0.478667
# [67]	train's binary_logloss: 0.403407	valid's binary_logloss: 0.478776
# [68]	train's binary_logloss: 0.40238	valid's binary_logloss: 0.4787
# [69]	train's binary_logloss: 0.401608	valid's binary_logloss: 0.478677
# [70]	train's binary_logloss: 0.400966	valid's binary_logloss: 0.478745
# [71]	train's binary_logloss: 0.4003	valid's binary_logloss: 0.478826
# [72]	train's binary_logloss: 0.399577	valid's binary_logloss: 0.479091
# [73]	train's binary_logloss: 0.398811	valid's binary_logloss: 0.479271
# [74]	train's binary_logloss: 0.397959	valid's binary_logloss: 0.478816
# [75]	train's binary_logloss: 0.39752	valid's binary_logloss: 0.478911
# [76]	train's binary_logloss: 0.396967	valid's binary_logloss: 0.479133
# [77]	train's binary_logloss: 0.396311	valid's binary_logloss: 0.479234
# [78]	train's binary_logloss: 0.395745	valid's binary_logloss: 0.479136
# [79]	train's binary_logloss: 0.39486	valid's binary_logloss: 0.478921
# [80]	train's binary_logloss: 0.393888	valid's binary_logloss: 0.478782
# [81]	train's binary_logloss: 0.39326	valid's binary_logloss: 0.478619
# [82]	train's binary_logloss: 0.392576	valid's binary_logloss: 0.478613
# [83]	train's binary_logloss: 0.391737	valid's binary_logloss: 0.478544
# [84]	train's binary_logloss: 0.391108	valid's binary_logloss: 0.478637
# [85]	train's binary_logloss: 0.39026	valid's binary_logloss: 0.47886
# [86]	train's binary_logloss: 0.389825	valid's binary_logloss: 0.47879
# [87]	train's binary_logloss: 0.389088	valid's binary_logloss: 0.478801
# [88]	train's binary_logloss: 0.388482	valid's binary_logloss: 0.47875
# [89]	train's binary_logloss: 0.387817	valid's binary_logloss: 0.478658
# [90]	train's binary_logloss: 0.386856	valid's binary_logloss: 0.478446
# [91]	train's binary_logloss: 0.386073	valid's binary_logloss: 0.478178
# [92]	train's binary_logloss: 0.385473	valid's binary_logloss: 0.477993
# [93]	train's binary_logloss: 0.384796	valid's binary_logloss: 0.478195
# [94]	train's binary_logloss: 0.383888	valid's binary_logloss: 0.477987
# [95]	train's binary_logloss: 0.383284	valid's binary_logloss: 0.478346
# [96]	train's binary_logloss: 0.382757	valid's binary_logloss: 0.478444
# [97]	train's binary_logloss: 0.382035	valid's binary_logloss: 0.478412
# [98]	train's binary_logloss: 0.381437	valid's binary_logloss: 0.478595
# [99]	train's binary_logloss: 0.380707	valid's binary_logloss: 0.478579
# [100]	train's binary_logloss: 0.380118	valid's binary_logloss: 0.478708
# 1       0
# 3       1
# 4       1
# 5       0
# 7       0
#        ..
# 9785    0
# 9786    0
# 9787    0
# 9788    0
# 9789    1
# Name: state, Length: 7833, dtype: int64
# [0 0 1 ... 0 0 1]
# [f1 score] tr:0.81, va:0.75
# -------------------- 2 --------------------
# (7833, 5) (7833,)
# (1958, 5) (1958,)
# [1]	train's binary_logloss: 0.660767	valid's binary_logloss: 0.666268
# [2]	train's binary_logloss: 0.633552	valid's binary_logloss: 0.643528
# [3]	train's binary_logloss: 0.610455	valid's binary_logloss: 0.624119
# [4]	train's binary_logloss: 0.590872	valid's binary_logloss: 0.608136
# [5]	train's binary_logloss: 0.573914	valid's binary_logloss: 0.594529
# [6]	train's binary_logloss: 0.55902	valid's binary_logloss: 0.582973
# [7]	train's binary_logloss: 0.546248	valid's binary_logloss: 0.573004
# [8]	train's binary_logloss: 0.53482	valid's binary_logloss: 0.564525
# [9]	train's binary_logloss: 0.524856	valid's binary_logloss: 0.55729
# [10]	train's binary_logloss: 0.515893	valid's binary_logloss: 0.550772
# [11]	train's binary_logloss: 0.507994	valid's binary_logloss: 0.545418
# [12]	train's binary_logloss: 0.500877	valid's binary_logloss: 0.540874
# [13]	train's binary_logloss: 0.49444	valid's binary_logloss: 0.537034
# [14]	train's binary_logloss: 0.488717	valid's binary_logloss: 0.533145
# [15]	train's binary_logloss: 0.483686	valid's binary_logloss: 0.530385
# [16]	train's binary_logloss: 0.478641	valid's binary_logloss: 0.527597
# [17]	train's binary_logloss: 0.474289	valid's binary_logloss: 0.525062
# [18]	train's binary_logloss: 0.470374	valid's binary_logloss: 0.523137
# [19]	train's binary_logloss: 0.466532	valid's binary_logloss: 0.521348
# [20]	train's binary_logloss: 0.463134	valid's binary_logloss: 0.519367
# [21]	train's binary_logloss: 0.46014	valid's binary_logloss: 0.518121
# [22]	train's binary_logloss: 0.457296	valid's binary_logloss: 0.51697
# [23]	train's binary_logloss: 0.454575	valid's binary_logloss: 0.515343
# [24]	train's binary_logloss: 0.45192	valid's binary_logloss: 0.514402
# [25]	train's binary_logloss: 0.449408	valid's binary_logloss: 0.512957
# [26]	train's binary_logloss: 0.446877	valid's binary_logloss: 0.511994
# [27]	train's binary_logloss: 0.444502	valid's binary_logloss: 0.510764
# [28]	train's binary_logloss: 0.442501	valid's binary_logloss: 0.509724
# [29]	train's binary_logloss: 0.440473	valid's binary_logloss: 0.509106
# [30]	train's binary_logloss: 0.438838	valid's binary_logloss: 0.508379
# [31]	train's binary_logloss: 0.436785	valid's binary_logloss: 0.507792
# [32]	train's binary_logloss: 0.435145	valid's binary_logloss: 0.507256
# [33]	train's binary_logloss: 0.433226	valid's binary_logloss: 0.507406
# [34]	train's binary_logloss: 0.431425	valid's binary_logloss: 0.506768
# [35]	train's binary_logloss: 0.429787	valid's binary_logloss: 0.50634
# [36]	train's binary_logloss: 0.428288	valid's binary_logloss: 0.505875
# [37]	train's binary_logloss: 0.427084	valid's binary_logloss: 0.505479
# [38]	train's binary_logloss: 0.425614	valid's binary_logloss: 0.505118
# [39]	train's binary_logloss: 0.424238	valid's binary_logloss: 0.504361
# [40]	train's binary_logloss: 0.422939	valid's binary_logloss: 0.504192
# [41]	train's binary_logloss: 0.421609	valid's binary_logloss: 0.504337
# [42]	train's binary_logloss: 0.420386	valid's binary_logloss: 0.504051
# [43]	train's binary_logloss: 0.419314	valid's binary_logloss: 0.503537
# [44]	train's binary_logloss: 0.418079	valid's binary_logloss: 0.503409
# [45]	train's binary_logloss: 0.417093	valid's binary_logloss: 0.503148
# [46]	train's binary_logloss: 0.416215	valid's binary_logloss: 0.502862
# [47]	train's binary_logloss: 0.415209	valid's binary_logloss: 0.502515
# [48]	train's binary_logloss: 0.414006	valid's binary_logloss: 0.502762
# [49]	train's binary_logloss: 0.412996	valid's binary_logloss: 0.502723
# [50]	train's binary_logloss: 0.412111	valid's binary_logloss: 0.502918
# [51]	train's binary_logloss: 0.411008	valid's binary_logloss: 0.503114
# [52]	train's binary_logloss: 0.410049	valid's binary_logloss: 0.503032
# [53]	train's binary_logloss: 0.408952	valid's binary_logloss: 0.503448
# [54]	train's binary_logloss: 0.407839	valid's binary_logloss: 0.503156
# [55]	train's binary_logloss: 0.406735	valid's binary_logloss: 0.503419
# [56]	train's binary_logloss: 0.405755	valid's binary_logloss: 0.503582
# [57]	train's binary_logloss: 0.404876	valid's binary_logloss: 0.50331
# [58]	train's binary_logloss: 0.403767	valid's binary_logloss: 0.503134
# [59]	train's binary_logloss: 0.402952	valid's binary_logloss: 0.503393
# [60]	train's binary_logloss: 0.402122	valid's binary_logloss: 0.503421
# [61]	train's binary_logloss: 0.401245	valid's binary_logloss: 0.502897
# [62]	train's binary_logloss: 0.400162	valid's binary_logloss: 0.502748
# [63]	train's binary_logloss: 0.399304	valid's binary_logloss: 0.50251
# [64]	train's binary_logloss: 0.398656	valid's binary_logloss: 0.502207
# [65]	train's binary_logloss: 0.398038	valid's binary_logloss: 0.501755
# [66]	train's binary_logloss: 0.396964	valid's binary_logloss: 0.502045
# [67]	train's binary_logloss: 0.395966	valid's binary_logloss: 0.502022
# [68]	train's binary_logloss: 0.394957	valid's binary_logloss: 0.502284
# [69]	train's binary_logloss: 0.393966	valid's binary_logloss: 0.502562
# [70]	train's binary_logloss: 0.393168	valid's binary_logloss: 0.502589
# [71]	train's binary_logloss: 0.392445	valid's binary_logloss: 0.502771
# [72]	train's binary_logloss: 0.391149	valid's binary_logloss: 0.502643
# [73]	train's binary_logloss: 0.390368	valid's binary_logloss: 0.50264
# [74]	train's binary_logloss: 0.389525	valid's binary_logloss: 0.502673
# [75]	train's binary_logloss: 0.388667	valid's binary_logloss: 0.502423
# [76]	train's binary_logloss: 0.387847	valid's binary_logloss: 0.50228
# [77]	train's binary_logloss: 0.387055	valid's binary_logloss: 0.502411
# [78]	train's binary_logloss: 0.386001	valid's binary_logloss: 0.502838
# [79]	train's binary_logloss: 0.38526	valid's binary_logloss: 0.502988
# [80]	train's binary_logloss: 0.384574	valid's binary_logloss: 0.502852
# [81]	train's binary_logloss: 0.384034	valid's binary_logloss: 0.502793
# [82]	train's binary_logloss: 0.383066	valid's binary_logloss: 0.503171
# [83]	train's binary_logloss: 0.382566	valid's binary_logloss: 0.503152
# [84]	train's binary_logloss: 0.381963	valid's binary_logloss: 0.503098
# [85]	train's binary_logloss: 0.381062	valid's binary_logloss: 0.503186
# [86]	train's binary_logloss: 0.380214	valid's binary_logloss: 0.503102
# [87]	train's binary_logloss: 0.379649	valid's binary_logloss: 0.503199
# [88]	train's binary_logloss: 0.378903	valid's binary_logloss: 0.503536
# [89]	train's binary_logloss: 0.378135	valid's binary_logloss: 0.503488
# [90]	train's binary_logloss: 0.377434	valid's binary_logloss: 0.503891
# [91]	train's binary_logloss: 0.376668	valid's binary_logloss: 0.503639
# [92]	train's binary_logloss: 0.375802	valid's binary_logloss: 0.503976
# [93]	train's binary_logloss: 0.375142	valid's binary_logloss: 0.504208
# [94]	train's binary_logloss: 0.374473	valid's binary_logloss: 0.504226
# [95]	train's binary_logloss: 0.373766	valid's binary_logloss: 0.504215
# [96]	train's binary_logloss: 0.37293	valid's binary_logloss: 0.504501
# [97]	train's binary_logloss: 0.37244	valid's binary_logloss: 0.504504
# [98]	train's binary_logloss: 0.371764	valid's binary_logloss: 0.504548
# [99]	train's binary_logloss: 0.370927	valid's binary_logloss: 0.504752
# [100]	train's binary_logloss: 0.37013	valid's binary_logloss: 0.50478
# 0       1
# 1       0
# 2       0
# 4       1
# 6       1
#        ..
# 9784    1
# 9787    0
# 9788    0
# 9789    1
# 9790    0
# Name: state, Length: 7833, dtype: int64
# [0 0 1 ... 0 1 0]
# [f1 score] tr:0.82, va:0.73
# -------------------- 3 --------------------
# (7833, 5) (7833,)
# (1958, 5) (1958,)
# [1]	train's binary_logloss: 0.661549	valid's binary_logloss: 0.66294
# [2]	train's binary_logloss: 0.635067	valid's binary_logloss: 0.637291
# [3]	train's binary_logloss: 0.612664	valid's binary_logloss: 0.61636
# [4]	train's binary_logloss: 0.593857	valid's binary_logloss: 0.598122
# [5]	train's binary_logloss: 0.577404	valid's binary_logloss: 0.582438
# [6]	train's binary_logloss: 0.563163	valid's binary_logloss: 0.569034
# [7]	train's binary_logloss: 0.550342	valid's binary_logloss: 0.558345
# [8]	train's binary_logloss: 0.539266	valid's binary_logloss: 0.548809
# [9]	train's binary_logloss: 0.529447	valid's binary_logloss: 0.540814
# [10]	train's binary_logloss: 0.520682	valid's binary_logloss: 0.533136
# [11]	train's binary_logloss: 0.513007	valid's binary_logloss: 0.526547
# [12]	train's binary_logloss: 0.506143	valid's binary_logloss: 0.521158
# [13]	train's binary_logloss: 0.499925	valid's binary_logloss: 0.516384
# [14]	train's binary_logloss: 0.494324	valid's binary_logloss: 0.511754
# [15]	train's binary_logloss: 0.489023	valid's binary_logloss: 0.508346
# [16]	train's binary_logloss: 0.484505	valid's binary_logloss: 0.505137
# [17]	train's binary_logloss: 0.479994	valid's binary_logloss: 0.501882
# [18]	train's binary_logloss: 0.476269	valid's binary_logloss: 0.499578
# [19]	train's binary_logloss: 0.472603	valid's binary_logloss: 0.496929
# [20]	train's binary_logloss: 0.46942	valid's binary_logloss: 0.494554
# [21]	train's binary_logloss: 0.466179	valid's binary_logloss: 0.49244
# [22]	train's binary_logloss: 0.463064	valid's binary_logloss: 0.490696
# [23]	train's binary_logloss: 0.460221	valid's binary_logloss: 0.489007
# [24]	train's binary_logloss: 0.457941	valid's binary_logloss: 0.487971
# [25]	train's binary_logloss: 0.455406	valid's binary_logloss: 0.487236
# [26]	train's binary_logloss: 0.453057	valid's binary_logloss: 0.486173
# [27]	train's binary_logloss: 0.450939	valid's binary_logloss: 0.485111
# [28]	train's binary_logloss: 0.448724	valid's binary_logloss: 0.484038
# [29]	train's binary_logloss: 0.446777	valid's binary_logloss: 0.483352
# [30]	train's binary_logloss: 0.445104	valid's binary_logloss: 0.48237
# [31]	train's binary_logloss: 0.443349	valid's binary_logloss: 0.481902
# [32]	train's binary_logloss: 0.441475	valid's binary_logloss: 0.480582
# [33]	train's binary_logloss: 0.439729	valid's binary_logloss: 0.480006
# [34]	train's binary_logloss: 0.438246	valid's binary_logloss: 0.479848
# [35]	train's binary_logloss: 0.436734	valid's binary_logloss: 0.479286
# [36]	train's binary_logloss: 0.435268	valid's binary_logloss: 0.479112
# [37]	train's binary_logloss: 0.434083	valid's binary_logloss: 0.478688
# [38]	train's binary_logloss: 0.433031	valid's binary_logloss: 0.478538
# [39]	train's binary_logloss: 0.431649	valid's binary_logloss: 0.478086
# [40]	train's binary_logloss: 0.430396	valid's binary_logloss: 0.478057
# [41]	train's binary_logloss: 0.42891	valid's binary_logloss: 0.478409
# [42]	train's binary_logloss: 0.427556	valid's binary_logloss: 0.478447
# [43]	train's binary_logloss: 0.426274	valid's binary_logloss: 0.478329
# [44]	train's binary_logloss: 0.424874	valid's binary_logloss: 0.478606
# [45]	train's binary_logloss: 0.423631	valid's binary_logloss: 0.478951
# [46]	train's binary_logloss: 0.422508	valid's binary_logloss: 0.478929
# [47]	train's binary_logloss: 0.421608	valid's binary_logloss: 0.479021
# [48]	train's binary_logloss: 0.420688	valid's binary_logloss: 0.479108
# [49]	train's binary_logloss: 0.419719	valid's binary_logloss: 0.478794
# [50]	train's binary_logloss: 0.418787	valid's binary_logloss: 0.479136
# [51]	train's binary_logloss: 0.417888	valid's binary_logloss: 0.478798
# [52]	train's binary_logloss: 0.417062	valid's binary_logloss: 0.478842
# [53]	train's binary_logloss: 0.416113	valid's binary_logloss: 0.478821
# [54]	train's binary_logloss: 0.415017	valid's binary_logloss: 0.47949
# [55]	train's binary_logloss: 0.413772	valid's binary_logloss: 0.479199
# [56]	train's binary_logloss: 0.412736	valid's binary_logloss: 0.479185
# [57]	train's binary_logloss: 0.412038	valid's binary_logloss: 0.478976
# [58]	train's binary_logloss: 0.411132	valid's binary_logloss: 0.478701
# [59]	train's binary_logloss: 0.410308	valid's binary_logloss: 0.478949
# [60]	train's binary_logloss: 0.409217	valid's binary_logloss: 0.478896
# [61]	train's binary_logloss: 0.408177	valid's binary_logloss: 0.478747
# [62]	train's binary_logloss: 0.407593	valid's binary_logloss: 0.478706
# [63]	train's binary_logloss: 0.406699	valid's binary_logloss: 0.47832
# [64]	train's binary_logloss: 0.405925	valid's binary_logloss: 0.478262
# [65]	train's binary_logloss: 0.405095	valid's binary_logloss: 0.477796
# [66]	train's binary_logloss: 0.404465	valid's binary_logloss: 0.478096
# [67]	train's binary_logloss: 0.403638	valid's binary_logloss: 0.478088
# [68]	train's binary_logloss: 0.403026	valid's binary_logloss: 0.477733
# [69]	train's binary_logloss: 0.40212	valid's binary_logloss: 0.477685
# [70]	train's binary_logloss: 0.401554	valid's binary_logloss: 0.477747
# [71]	train's binary_logloss: 0.400577	valid's binary_logloss: 0.478038
# [72]	train's binary_logloss: 0.399656	valid's binary_logloss: 0.477607
# [73]	train's binary_logloss: 0.39887	valid's binary_logloss: 0.47705
# [74]	train's binary_logloss: 0.397989	valid's binary_logloss: 0.476858
# [75]	train's binary_logloss: 0.397235	valid's binary_logloss: 0.476744
# [76]	train's binary_logloss: 0.396297	valid's binary_logloss: 0.477001
# [77]	train's binary_logloss: 0.395494	valid's binary_logloss: 0.477096
# [78]	train's binary_logloss: 0.394827	valid's binary_logloss: 0.477264
# [79]	train's binary_logloss: 0.393923	valid's binary_logloss: 0.477195
# [80]	train's binary_logloss: 0.393254	valid's binary_logloss: 0.477665
# [81]	train's binary_logloss: 0.392553	valid's binary_logloss: 0.477967
# [82]	train's binary_logloss: 0.391563	valid's binary_logloss: 0.477825
# [83]	train's binary_logloss: 0.390777	valid's binary_logloss: 0.477981
# [84]	train's binary_logloss: 0.389897	valid's binary_logloss: 0.477848
# [85]	train's binary_logloss: 0.389416	valid's binary_logloss: 0.477715
# [86]	train's binary_logloss: 0.388825	valid's binary_logloss: 0.477772
# [87]	train's binary_logloss: 0.388096	valid's binary_logloss: 0.478194
# [88]	train's binary_logloss: 0.387339	valid's binary_logloss: 0.478187
# [89]	train's binary_logloss: 0.386863	valid's binary_logloss: 0.478035
# [90]	train's binary_logloss: 0.3862	valid's binary_logloss: 0.477843
# [91]	train's binary_logloss: 0.385543	valid's binary_logloss: 0.478052
# [92]	train's binary_logloss: 0.38474	valid's binary_logloss: 0.478484
# [93]	train's binary_logloss: 0.383999	valid's binary_logloss: 0.478495
# [94]	train's binary_logloss: 0.383439	valid's binary_logloss: 0.47843
# [95]	train's binary_logloss: 0.382634	valid's binary_logloss: 0.47856
# [96]	train's binary_logloss: 0.381771	valid's binary_logloss: 0.478633
# [97]	train's binary_logloss: 0.381312	valid's binary_logloss: 0.478805
# [98]	train's binary_logloss: 0.380515	valid's binary_logloss: 0.478936
# [99]	train's binary_logloss: 0.379675	valid's binary_logloss: 0.478823
# [100]	train's binary_logloss: 0.379132	valid's binary_logloss: 0.478686
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 9785    0
# 9786    0
# 9787    0
# 9788    0
# 9790    0
# Name: state, Length: 7833, dtype: int64
# [0 0 1 ... 0 0 0]
# [f1 score] tr:0.81, va:0.74
# -------------------- 4 --------------------
# (7833, 5) (7833,)
# (1958, 5) (1958,)
# [1]	train's binary_logloss: 0.661336	valid's binary_logloss: 0.662539
# [2]	train's binary_logloss: 0.635284	valid's binary_logloss: 0.637549
# [3]	train's binary_logloss: 0.613349	valid's binary_logloss: 0.616514
# [4]	train's binary_logloss: 0.594202	valid's binary_logloss: 0.598743
# [5]	train's binary_logloss: 0.577764	valid's binary_logloss: 0.583146
# [6]	train's binary_logloss: 0.563229	valid's binary_logloss: 0.569673
# [7]	train's binary_logloss: 0.550598	valid's binary_logloss: 0.557717
# [8]	train's binary_logloss: 0.539292	valid's binary_logloss: 0.547827
# [9]	train's binary_logloss: 0.529835	valid's binary_logloss: 0.539441
# [10]	train's binary_logloss: 0.521093	valid's binary_logloss: 0.531787
# [11]	train's binary_logloss: 0.513266	valid's binary_logloss: 0.525292
# [12]	train's binary_logloss: 0.506254	valid's binary_logloss: 0.519023
# [13]	train's binary_logloss: 0.500148	valid's binary_logloss: 0.513781
# [14]	train's binary_logloss: 0.494752	valid's binary_logloss: 0.509051
# [15]	train's binary_logloss: 0.48987	valid's binary_logloss: 0.504361
# [16]	train's binary_logloss: 0.485277	valid's binary_logloss: 0.500185
# [17]	train's binary_logloss: 0.48088	valid's binary_logloss: 0.496715
# [18]	train's binary_logloss: 0.477093	valid's binary_logloss: 0.492703
# [19]	train's binary_logloss: 0.473383	valid's binary_logloss: 0.489985
# [20]	train's binary_logloss: 0.469776	valid's binary_logloss: 0.487261
# [21]	train's binary_logloss: 0.466777	valid's binary_logloss: 0.484997
# [22]	train's binary_logloss: 0.463766	valid's binary_logloss: 0.482535
# [23]	train's binary_logloss: 0.461001	valid's binary_logloss: 0.480818
# [24]	train's binary_logloss: 0.458418	valid's binary_logloss: 0.479243
# [25]	train's binary_logloss: 0.455862	valid's binary_logloss: 0.477644
# [26]	train's binary_logloss: 0.453734	valid's binary_logloss: 0.476377
# [27]	train's binary_logloss: 0.451399	valid's binary_logloss: 0.475277
# [28]	train's binary_logloss: 0.449351	valid's binary_logloss: 0.474121
# [29]	train's binary_logloss: 0.447311	valid's binary_logloss: 0.473559
# [30]	train's binary_logloss: 0.445319	valid's binary_logloss: 0.47294
# [31]	train's binary_logloss: 0.443581	valid's binary_logloss: 0.472598
# [32]	train's binary_logloss: 0.442043	valid's binary_logloss: 0.471869
# [33]	train's binary_logloss: 0.440422	valid's binary_logloss: 0.471135
# [34]	train's binary_logloss: 0.438792	valid's binary_logloss: 0.470995
# [35]	train's binary_logloss: 0.437509	valid's binary_logloss: 0.470524
# [36]	train's binary_logloss: 0.435921	valid's binary_logloss: 0.469882
# [37]	train's binary_logloss: 0.434533	valid's binary_logloss: 0.469638
# [38]	train's binary_logloss: 0.433228	valid's binary_logloss: 0.469361
# [39]	train's binary_logloss: 0.431456	valid's binary_logloss: 0.469047
# [40]	train's binary_logloss: 0.43024	valid's binary_logloss: 0.468674
# [41]	train's binary_logloss: 0.429073	valid's binary_logloss: 0.468818
# [42]	train's binary_logloss: 0.428022	valid's binary_logloss: 0.468589
# [43]	train's binary_logloss: 0.426609	valid's binary_logloss: 0.468218
# [44]	train's binary_logloss: 0.425337	valid's binary_logloss: 0.468021
# [45]	train's binary_logloss: 0.424206	valid's binary_logloss: 0.467776
# [46]	train's binary_logloss: 0.422911	valid's binary_logloss: 0.467431
# [47]	train's binary_logloss: 0.421976	valid's binary_logloss: 0.467229
# [48]	train's binary_logloss: 0.421017	valid's binary_logloss: 0.467065
# [49]	train's binary_logloss: 0.420174	valid's binary_logloss: 0.466904
# [50]	train's binary_logloss: 0.41921	valid's binary_logloss: 0.466806
# [51]	train's binary_logloss: 0.418226	valid's binary_logloss: 0.467048
# [52]	train's binary_logloss: 0.417077	valid's binary_logloss: 0.466764
# [53]	train's binary_logloss: 0.416033	valid's binary_logloss: 0.466873
# [54]	train's binary_logloss: 0.414719	valid's binary_logloss: 0.466604
# [55]	train's binary_logloss: 0.413759	valid's binary_logloss: 0.466337
# [56]	train's binary_logloss: 0.412324	valid's binary_logloss: 0.46605
# [57]	train's binary_logloss: 0.411226	valid's binary_logloss: 0.465943
# [58]	train's binary_logloss: 0.410632	valid's binary_logloss: 0.466005
# [59]	train's binary_logloss: 0.40979	valid's binary_logloss: 0.465692
# [60]	train's binary_logloss: 0.4092	valid's binary_logloss: 0.465725
# [61]	train's binary_logloss: 0.407993	valid's binary_logloss: 0.465475
# [62]	train's binary_logloss: 0.40725	valid's binary_logloss: 0.46532
# [63]	train's binary_logloss: 0.40651	valid's binary_logloss: 0.465326
# [64]	train's binary_logloss: 0.405778	valid's binary_logloss: 0.465861
# [65]	train's binary_logloss: 0.404826	valid's binary_logloss: 0.466064
# [66]	train's binary_logloss: 0.404222	valid's binary_logloss: 0.465894
# [67]	train's binary_logloss: 0.403122	valid's binary_logloss: 0.465985
# [68]	train's binary_logloss: 0.402151	valid's binary_logloss: 0.466198
# [69]	train's binary_logloss: 0.401397	valid's binary_logloss: 0.466381
# [70]	train's binary_logloss: 0.400658	valid's binary_logloss: 0.466626
# [71]	train's binary_logloss: 0.39996	valid's binary_logloss: 0.466875
# [72]	train's binary_logloss: 0.399075	valid's binary_logloss: 0.466421
# [73]	train's binary_logloss: 0.39843	valid's binary_logloss: 0.466542
# [74]	train's binary_logloss: 0.39761	valid's binary_logloss: 0.466659
# [75]	train's binary_logloss: 0.396818	valid's binary_logloss: 0.466841
# [76]	train's binary_logloss: 0.395961	valid's binary_logloss: 0.466582
# [77]	train's binary_logloss: 0.395328	valid's binary_logloss: 0.466943
# [78]	train's binary_logloss: 0.394639	valid's binary_logloss: 0.466879
# [79]	train's binary_logloss: 0.393729	valid's binary_logloss: 0.467388
# [80]	train's binary_logloss: 0.39252	valid's binary_logloss: 0.466978
# [81]	train's binary_logloss: 0.392017	valid's binary_logloss: 0.466999
# [82]	train's binary_logloss: 0.391341	valid's binary_logloss: 0.46719
# [83]	train's binary_logloss: 0.390573	valid's binary_logloss: 0.467262
# [84]	train's binary_logloss: 0.38985	valid's binary_logloss: 0.467102
# [85]	train's binary_logloss: 0.388924	valid's binary_logloss: 0.467204
# [86]	train's binary_logloss: 0.388386	valid's binary_logloss: 0.467424
# [87]	train's binary_logloss: 0.387659	valid's binary_logloss: 0.467114
# [88]	train's binary_logloss: 0.386982	valid's binary_logloss: 0.467088
# [89]	train's binary_logloss: 0.385935	valid's binary_logloss: 0.467077
# [90]	train's binary_logloss: 0.384996	valid's binary_logloss: 0.466574
# [91]	train's binary_logloss: 0.384285	valid's binary_logloss: 0.467133
# [92]	train's binary_logloss: 0.383505	valid's binary_logloss: 0.467213
# [93]	train's binary_logloss: 0.382836	valid's binary_logloss: 0.467068
# [94]	train's binary_logloss: 0.382004	valid's binary_logloss: 0.466871
# [95]	train's binary_logloss: 0.381222	valid's binary_logloss: 0.466713
# [96]	train's binary_logloss: 0.380346	valid's binary_logloss: 0.466727
# [97]	train's binary_logloss: 0.379648	valid's binary_logloss: 0.466825
# [98]	train's binary_logloss: 0.378883	valid's binary_logloss: 0.467185
# [99]	train's binary_logloss: 0.378371	valid's binary_logloss: 0.467303
# [100]	train's binary_logloss: 0.377619	valid's binary_logloss: 0.467651
# 0       1
# 1       0
# 2       0
# 3       1
# 5       0
#        ..
# 9785    0
# 9786    0
# 9787    0
# 9789    1
# 9790    0
# Name: state, Length: 7833, dtype: int64
# [0 0 0 ... 0 1 0]
# [f1 score] tr:0.82, va:0.75
# ==================== result ====================
# [[0.         0.81336747 0.73423181]
#  [1.         0.80798606 0.74574468]
#  [2.         0.81825525 0.72521552]
#  [3.         0.81233316 0.73758099]
#  [4.         0.81604091 0.74972678]]

# %%
sub = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/sample_submit.csv', header=None)
sub
# Out:
#                0  1
# 0     test_00000  1
# 1     test_00001  0
# 2     test_00002  0
# 3     test_00003  0
# 4     test_00004  1
# ...          ... ..
# 9795  test_09795  0
# 9796  test_09796  0
# 9797  test_09797  1
# 9798  test_09798  0
# 9799  test_09799  0
#
# [9800 rows x 2 columns]

# %%
x_test = test[['goal', 'country', 'duration', 'category1', 'category2']]
id_test = test['id']

for column in categorical_features:
  target_column = x_test[column]
  le = LabelEncoder()
  le.fit(target_column)
  label_encoded_column = le.transform(target_column)
  x_test[column] = pd.Series(label_encoded_column).astype('category')

y_test_pred = model.predict(x_test)
y_test_pred = np.where(y_test_pred > 0.5, 1, 0)
print(id_test)
print(y_test_pred)
df_submit = pd.DataFrame({'id':id_test, 'pred':y_test_pred})
df_submit.to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/submit_1.csv', index=None, header=None)
# Out:
# 0       test_00000
# 1       test_00001
# 2       test_00002
# 3       test_00003
# 4       test_00004
#            ...
# 9795    test_09795
# 9796    test_09796
# 9797    test_09797
# 9798    test_09798
# 9799    test_09799
# Name: id, Length: 9800, dtype: object
# [1 1 1 ... 0 0 0]
