# %%
import os

class Config_first:
    # 出力フォルダ名
    NAME = "test-10-bert-deberta-base-epoch10"

    # 学習するモデルの読み込み
    # https://huggingface.co/ からモデルのパスを指定
    # 例えば, "microsoft/deberta-base"
    MODEL_PATH = "roberta-base"
    # MODEL_PATH = "microsoft/deberta-v3-large"


    # ベースとなるディレクトリパスの指定
    COLAB_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    DRIVE_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    # DRIVE_PATH = os.path.join(COLAB_PATH, AUTHOR)

    # シード値
    seed = 42
    
    # cross-validaitonの分割数
    num_fold = 3
    # 学習するfold
    trn_fold = [0, 1, 2]
    
    # batct_sizeの設定
    batch_size = 32
    
    # epoch数の設定
    n_epochs = 5
    
    # トークン数の最大の長さの設定
    max_len = 256

    # 学習率の設定
    lr = 2e-5

    # optimizer等の設定
    weight_decay = 2e-5
    beta = (0.9, 0.98)
    num_warmup_steps_rate = 0.01
    clip_grad_norm = None
    gradient_accumulation_steps = 1
    num_eval = 1

# %%
class Config_second:
    # 出力フォルダ名
    NAME = "test-10-bert-deberta-base-epoch10"

    # 学習するモデルの読み込み
    # https://huggingface.co/ からモデルのパスを指定
    # 例えば, "microsoft/deberta-base"
    MODEL_PATH = "microsoft/deberta-v3-base"


    # ベースとなるディレクトリパスの指定
    COLAB_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    DRIVE_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    # DRIVE_PATH = os.path.join(COLAB_PATH, AUTHOR)

    # シード値
    seed = 42
    
    # cross-validaitonの分割数
    num_fold = 3
    # 学習するfold
    trn_fold = [0, 1, 2]
    
    # batct_sizeの設定
    batch_size = 32
    
    # epoch数の設定
    n_epochs = 4
    
    # トークン数の最大の長さの設定
    max_len = 256

    # 学習率の設定
    lr = 2e-5

    # optimizer等の設定
    weight_decay = 2e-5
    beta = (0.9, 0.98)
    num_warmup_steps_rate = 0.01
    clip_grad_norm = None
    gradient_accumulation_steps = 1
    num_eval = 1

# %%
class Config_third:
    # 出力フォルダ名
    NAME = "test-10-bert-deberta-base-epoch10"

    # 学習するモデルの読み込み
    # https://huggingface.co/ からモデルのパスを指定
    # 例えば, "microsoft/deberta-base"
    MODEL_PATH = "dbmdz/bert-base-french-europeana-cased"


    # ベースとなるディレクトリパスの指定
    COLAB_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    DRIVE_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    # DRIVE_PATH = os.path.join(COLAB_PATH, AUTHOR)

    # シード値
    seed = 42
    
    # cross-validaitonの分割数
    num_fold = 3
    # 学習するfold
    trn_fold = [0, 1, 2]
    
    # batct_sizeの設定
    batch_size = 32
    
    # epoch数の設定
    n_epochs = 4
    
    # トークン数の最大の長さの設定
    max_len = 256

    # 学習率の設定
    lr = 2e-5

    # optimizer等の設定
    weight_decay = 2e-5
    beta = (0.9, 0.98)
    num_warmup_steps_rate = 0.01
    clip_grad_norm = None
    gradient_accumulation_steps = 1
    num_eval = 1

# %%
class Config_fourth:
    # 出力フォルダ名
    NAME = "test-10-bert-deberta-base-epoch10"

    # 学習するモデルの読み込み
    # https://huggingface.co/ からモデルのパスを指定
    # 例えば, "microsoft/deberta-base"
    MODEL_PATH = "bert-base-uncased"


    # ベースとなるディレクトリパスの指定
    COLAB_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    DRIVE_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    # DRIVE_PATH = os.path.join(COLAB_PATH, AUTHOR)

    # シード値
    seed = 42
    
    # cross-validaitonの分割数
    num_fold = 3
    # 学習するfold
    trn_fold = [0, 1, 2]
    
    # batct_sizeの設定
    batch_size = 32
    
    # epoch数の設定
    n_epochs = 4
    
    # トークン数の最大の長さの設定
    max_len = 256

    # 学習率の設定
    lr = 2e-5

    # optimizer等の設定
    weight_decay = 2e-5
    beta = (0.9, 0.98)
    num_warmup_steps_rate = 0.01
    clip_grad_norm = None
    gradient_accumulation_steps = 1
    num_eval = 1

# %%
class Config_fifth:
    # 出力フォルダ名
    NAME = "test-10-bert-deberta-base-epoch10"

    # 学習するモデルの読み込み
    # https://huggingface.co/ からモデルのパスを指定
    # 例えば, "microsoft/deberta-base"
    MODEL_PATH = "microsoft/deberta-v3-base"


    # ベースとなるディレクトリパスの指定
    COLAB_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    DRIVE_PATH = "/content/drive/MyDrive/signate/MUFG Data Science Champion Ship" 
    # DRIVE_PATH = os.path.join(COLAB_PATH, AUTHOR)

    # シード値
    seed = 42
    
    # cross-validaitonの分割数
    num_fold = 3
    # 学習するfold
    trn_fold = [0, 1, 2]
    
    # batct_sizeの設定
    batch_size = 32
    
    # epoch数の設定
    n_epochs = 4
    
    # トークン数の最大の長さの設定
    max_len = 256

    # 学習率の設定
    lr = 2e-5

    # optimizer等の設定
    weight_decay = 2e-5
    beta = (0.9, 0.98)
    num_warmup_steps_rate = 0.01
    clip_grad_norm = None
    gradient_accumulation_steps = 1
    num_eval = 1

# %%
# ========================================
# Library
# ========================================
import os
import gc
import re
import sys
import json
import time
import shutil
import joblib
import random
import requests
import warnings
warnings.filterwarnings('ignore')
from ast import literal_eval

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import scipy 
import itertools
from pathlib import Path
from glob import glob
from tqdm.auto import tqdm
from sklearn.model_selection import (
    StratifiedKFold, 
    KFold, 
    GroupKFold,
    StratifiedGroupKFold,
)
from sklearn.metrics import (
    accuracy_score, 
    f1_score,
    roc_auc_score,
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from torch.cuda.amp import autocast, GradScaler

from html.parser import HTMLParser
from collections import defaultdict

from bs4 import BeautifulSoup

# !pip install sentence_transformers

from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder

import lightgbm as lgb

from google.colab import drive
if not os.path.isdir('/content/drive'):
    drive.mount('/content/drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 1.8 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.22.1-py3-none-any.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 4.2 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.13.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 53.1 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 70.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.12.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 50.4 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence_transformers) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=cd270fd4432e3b2f42407ac704883073cbda37986fdc2fcc5e27350c7155c653
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
# Successfully installed huggingface-hub-0.9.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.12.1 transformers-4.22.1
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# Mounted at /content/drive

# %%
def setup(cfg):
    cfg.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # mount
    from google.colab import drive
    if not os.path.isdir('/content/drive'):
        drive.mount('/content/drive') 

    # pip install
    ! pip install -q transformers
    ! pip install -q sentencepiece

    # set dirs
    cfg.DRIVE = cfg.DRIVE_PATH
    cfg.EXP = (cfg.NAME if cfg.NAME is not None 
        else requests.get('http://172.28.0.2:9000/api/sessions').json()[0]['name'][:-6]
    )
    cfg.INPUT = os.path.join(cfg.DRIVE, 'Input')
    cfg.OUTPUT = os.path.join(cfg.DRIVE, 'Output')
    cfg.DATASET = os.path.join(cfg.DRIVE, 'Dataset')

    cfg.OUTPUT_EXP = os.path.join(cfg.OUTPUT, cfg.EXP) 
    cfg.EXP_MODEL = os.path.join(cfg.OUTPUT_EXP, 'model')
    cfg.EXP_FIG = os.path.join(cfg.OUTPUT_EXP, 'fig')
    cfg.EXP_PREDS = os.path.join(cfg.OUTPUT_EXP, 'preds')

    # make dirs
    for d in [cfg.INPUT, cfg.EXP_MODEL, cfg.EXP_FIG, cfg.EXP_PREDS]:
        os.makedirs(d, exist_ok=True)
    return cfg

# %%
# =====================
# Utils
# =====================
# Seed
def set_seed(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# KFold
def get_stratifiedkfold(train, target_col, n_splits, seed):
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    generator = kf.split(train, train[target_col])
    fold_series = []
    for fold, (idx_train, idx_valid) in enumerate(generator):
        fold_series.append(pd.Series(fold, index=idx_valid))
    fold_series = pd.concat(fold_series).sort_index()
    return fold_series

# collatte
def collatte(inputs, labels=None):
    mask_len = int(inputs["attention_mask"].sum(axis=1).max())
    if not labels is None:
        inputs = {
            "input_ids" : inputs['input_ids'][:,:mask_len],
            "attention_mask" : inputs['attention_mask'][:,:mask_len],
        }
        labels =  labels[:,:mask_len]
        return inputs, labels, mask_len
                
    else:
        inputs = {
            "input_ids" : inputs['input_ids'][:,:mask_len],
            "attention_mask" : inputs['attention_mask'][:,:mask_len],
        }
        return inputs, mask_len

# %%
# =====================
# Dataset & Model
# =====================
class BERTDataset(Dataset):
    def __init__(self, cfg, texts, labels=None):
        self.cfg = cfg
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, index):
        inputs = self.prepare_input(self.cfg, self.texts[index])
        if self.labels is not None:
            label = torch.tensor(self.labels[index], dtype=torch.int64)
            return inputs, label
        else:
            return inputs
    
    @staticmethod
    def prepare_input(cfg, text):
        inputs = cfg.tokenizer(
            text,
            add_special_tokens=True,
            max_length=cfg.max_len,
            padding="max_length",
            truncation=True,
            return_offsets_mapping=False,
        )
        for k, v in inputs.items():
            inputs[k] = torch.tensor(v, dtype=torch.long)
        return inputs


class BERTModel(nn.Module):
    def __init__(self, cfg, criterion=None):
        super().__init__()
        self.cfg = cfg
        self.criterion = criterion
        self.config = AutoConfig.from_pretrained(
            cfg.MODEL_PATH,
            output_hidden_states=True
        )
        self.backbone = AutoModel.from_pretrained(
            cfg.MODEL_PATH, 
            config=self.config
        )
        self.fc = nn.Sequential(
            nn.Linear(self.config.hidden_size, 2),
        )
    
    def forward(self, inputs, labels=None):
        outputs = self.backbone(**inputs)["last_hidden_state"]
        outputs = outputs[:, 0, :]
        if labels is not None:
            logits = self.fc(outputs)
            loss = self.criterion(logits, labels)
            return logits, loss
        else:
            logits = self.fc(outputs)
            return logits

# %%
def training(cfg, train):
    # =====================
    # Training
    # =====================
    set_seed(cfg.seed)
    oof_pred = np.zeros((len(train), 2), dtype=np.float32)
    
    # 損失関数
    criterion = nn.CrossEntropyLoss()

    for fold in cfg.trn_fold:
        print('-'*20, fold, '-'*20)
        # Dataset,Dataloaderの設定
        train_df = train.loc[cfg.folds!=fold]
        valid_df = train.loc[cfg.folds==fold]
        train_idx = list(train_df.index)
        valid_idx = list(valid_df.index)

        train_dataset = BERTDataset(
            cfg,
            train_df['html_content'].to_numpy(), 
            train_df['state'].to_numpy(),
        )
        valid_dataset = BERTDataset(
            cfg, 
            valid_df['html_content'].to_numpy(), 
            valid_df['state'].to_numpy()
        )
        train_loader = DataLoader(
            dataset=train_dataset, 
            batch_size=cfg.batch_size, 
            shuffle=True,
            pin_memory=True,
            drop_last=True
        )
        valid_loader = DataLoader(
            dataset=valid_dataset,
            batch_size=cfg.batch_size,
            shuffle=False,
            pin_memory=True,
            drop_last=False
        )

        # 初期化
        best_val_preds = None
        best_val_score = -1

        # modelの読み込み
        model = BERTModel(cfg, criterion)
        model = model.to(cfg.device)

        # optimizer，schedulerの設定
        param_optimizer = list(model.named_parameters())
        no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
        optimizer_grouped_parameters = []
        optimizer_grouped_parameters.append({
            'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 
            'weight_decay': cfg.weight_decay
        })
        optimizer_grouped_parameters.append({
            'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 
            'weight_decay': 0.0
        })
        optimizer = AdamW(
            optimizer_grouped_parameters,
            lr=cfg.lr,
            betas=cfg.beta,
            weight_decay=cfg.weight_decay,
        )
        num_train_optimization_steps = int(
            len(train_loader) * cfg.n_epochs // cfg.gradient_accumulation_steps
        )
        num_warmup_steps = int(num_train_optimization_steps * cfg.num_warmup_steps_rate)
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=num_warmup_steps,
            num_training_steps=num_train_optimization_steps
        )
        num_eval_step = len(train_loader) // cfg.num_eval + cfg.num_eval
        
        for epoch in range(cfg.n_epochs):
            # training
            print(f"# ============ start epoch:{epoch} ============== #")
            model.train() 
            val_losses_batch = []
            scaler = GradScaler()
            with tqdm(train_loader, total=len(train_loader)) as pbar:
                for step, (inputs, labels) in enumerate(pbar):
                    inputs, max_len = collatte(inputs)
                    for k, v in inputs.items():
                        inputs[k] = v.to(cfg.device)
                    labels = labels.to(cfg.device)

                    optimizer.zero_grad()
                    with autocast():
                        output, loss = model(inputs, labels)
                    pbar.set_postfix({
                        'loss': loss.item(),
                        'lr': scheduler.get_lr()[0]
                    })

                    if cfg.gradient_accumulation_steps > 1:
                        loss = loss / cfg.gradient_accumulation_steps
                    scaler.scale(loss).backward()
                    if cfg.clip_grad_norm is not None:
                        torch.nn.utils.clip_grad_norm_(
                            model.parameters(), 
                            cfg.clip_grad_norm
                        )
                    if (step+1) % cfg.gradient_accumulation_steps == 0:
                        scaler.step(optimizer)
                        scaler.update()
                        scheduler.step()
                
            # evaluating
            val_preds = []
            val_losses = []
            val_nums = []
            model.eval()
            with torch.no_grad():
                with tqdm(valid_loader, total=len(valid_loader)) as pbar:
                    for (inputs, labels) in pbar:
                        inputs, max_len = collatte(inputs)
                        for k, v in inputs.items():
                            inputs[k] = v.to(cfg.device)
                        labels = labels.to(cfg.device)
                        with autocast():
                            output, loss = model(inputs, labels)
                        output = output.sigmoid().detach().cpu().numpy()
                        val_preds.append(output)
                        val_losses.append(loss.item() * len(labels))
                        val_nums.append(len(labels))
                        pbar.set_postfix({
                            'val_loss': loss.item()
                        })

            val_preds = np.concatenate(val_preds)
            val_loss = sum(val_losses) / sum(val_nums)
            score = f1_score(np.argmax(val_preds, axis=1), valid_df['state'], average='macro')
            val_log = {
                'val_loss': val_loss,
                'score': score,
            }
            display(val_log)
            if best_val_score < score:
                print("save model weight")
                best_val_preds = val_preds
                best_val_score = score
                torch.save(
                    model.state_dict(), 
                    os.path.join(cfg.EXP_MODEL, f"fold{fold}.pth")
                )

        oof_pred[valid_idx] = best_val_preds.astype(np.float32)
        np.save(os.path.join(cfg.EXP_PREDS, f'oof_pred_fold{fold}.npy'), best_val_preds)
        del model; gc.collect()

    # scoring
    np.save(os.path.join(cfg.EXP_PREDS, 'oof_pred.npy'), oof_pred)
    score = f1_score(np.argmax(oof_pred, axis=1), train['state'], average='macro')
    print('CV:', round(score, 5))
    return oof_pred

# %%
def inferring(cfg, test):
    print('\n'.join(cfg.model_weights))
    sub_pred = np.zeros((len(test), 2), dtype=np.float32)
    for fold, model_weight in enumerate(cfg.model_weights):
        # dataset, dataloader
        test_dataset = BERTDataset(
            cfg,
            test['html_content'].to_numpy()
        )
        test_loader = DataLoader(
            dataset=test_dataset, 
            batch_size=cfg.batch_size, 
            shuffle=False,
            pin_memory=True
        )
        model = BERTModel(cfg)
        model.load_state_dict(torch.load(model_weight))
        model = model.to(cfg.device)

        model.eval()
        fold_pred = []
        with torch.no_grad():
            for inputs in tqdm(test_loader, total=len(test_loader)):
                inputs, max_len = collatte(inputs)
                for k, v in inputs.items():
                    inputs[k] = v.to(cfg.device)
                with autocast():
                    output = model(inputs)
                output = output.softmax(axis=1).detach().cpu().numpy()
                fold_pred.append(output)
        fold_pred = np.concatenate(fold_pred)
        np.save(os.path.join(cfg.EXP_PREDS, f'sub_pred_fold{fold}.npy'), fold_pred)
        sub_pred += fold_pred / len(cfg.model_weights)
        del model; gc.collect()
    np.save(os.path.join(cfg.EXP_PREDS, f'sub_pred.npy'), sub_pred)
    return sub_pred

# %%
import transformers
from transformers import AutoConfig, AutoModel, AutoTokenizer
from transformers import AdamW, get_linear_schedule_with_warmup

# %%
def cleaning(texts):
  clean_texts = []
  for text in texts:
    text = remove_tag(text)
    clean_texts.append(text)
  return clean_texts

def remove_tag(x):
  p = re.compile(r"<[^>]*?>")
  return p.sub('',x)

# %%
# =====================
# Main
# =====================
# セットアップ
cfg = setup(Config_first)

# データの読み込み
train = pd.read_csv(os.path.join(cfg.INPUT, 'train.csv'))
test = pd.read_csv(os.path.join(cfg.INPUT, 'test.csv'))
pred = pd.read_csv(os.path.join(cfg.INPUT, 'sample_submit.csv'), header=None)

TEXT_COLUMNS = ['goal', 'country', 'duration', 'category1', 'category2', 'html_content']

# tokenizerの読み込み
cfg.tokenizer = AutoTokenizer.from_pretrained(cfg.MODEL_PATH)

train['html_content'] = train[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(train[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)
test['html_content'] = test[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(test[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)

# validationデータの設定
cfg.folds = get_stratifiedkfold(train, 'state', cfg.num_fold, cfg.seed)
cfg.folds.to_csv(os.path.join(cfg.EXP_PREDS, 'folds.csv'))

# BERTの学習
oof_pred_1 = training(cfg, train)
oof_1 = np.argmax(oof_pred_1, axis=1)
oof_1 = oof_1.astype(int)
print('#######################')
print(oof_1)

# BERTの推論
cfg.model_weights = [p for p in sorted(glob(os.path.join(cfg.EXP_MODEL, 'fold*.pth')))]
sub_pred = inferring(cfg, test)
pred['test_1'] = np.argmax(sub_pred, axis=1)
pred['test_1'] = pred['test_1'].astype(int)
# Out:
# -------------------- 0 --------------------
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4714696676123376, 'score': 0.7625594692505783}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4181533029266432, 'score': 0.7840816243185953}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.46327929958408953, 'score': 0.7816720762519771}
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4627365551742853, 'score': 0.793693480835592}
# save model weight
# # ============ start epoch:4 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5088823895682307, 'score': 0.7960152834934431}
# save model weight
# -------------------- 1 --------------------
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4755781596782161, 'score': 0.7699131574380116}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4461974013669818, 'score': 0.7765145954459433}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4305497177091299, 'score': 0.7951002034327095}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4659844362268261, 'score': 0.7964015840357181}
# save model weight
# # ============ start epoch:4 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5130890556702427, 'score': 0.7965815917218498}
# save model weight
# -------------------- 2 --------------------
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.666298560156546, 'score': 0.625159043367622}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4395050248356637, 'score': 0.7872171410831081}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4239887496901187, 'score': 0.798598695277662}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.440837995656385, 'score': 0.8052181114756995}
# save model weight
# # ============ start epoch:4 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5115089723660542, 'score': 0.799031588328539}
# CV: 0.79935
# #######################
# [1 0 1 ... 0 1 0]
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold0.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold1.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold2.pth
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]

# %%
cfg = setup(Config_second)

# データの読み込み
train = pd.read_csv(os.path.join(cfg.INPUT, 'train.csv'))
test = pd.read_csv(os.path.join(cfg.INPUT, 'test.csv'))

TEXT_COLUMNS = ['goal', 'country', 'duration', 'category1', 'category2', 'html_content']

# tokenizerの読み込み
cfg.tokenizer = AutoTokenizer.from_pretrained(cfg.MODEL_PATH)

train['html_content'] = train[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(train[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)
test['html_content'] = test[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(test[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)

# validationデータの設定
cfg.folds = get_stratifiedkfold(train, 'state', cfg.num_fold, cfg.seed)
cfg.folds.to_csv(os.path.join(cfg.EXP_PREDS, 'folds.csv'))

# BERTの学習
oof_pred_2 = training(cfg, train)
oof_2 = np.argmax(oof_pred_2, axis=1)
oof_2 = oof_2.astype(int)

# BERTの推論
cfg.model_weights = [p for p in sorted(glob(os.path.join(cfg.EXP_MODEL, 'fold*.pth')))]
sub_pred = inferring(cfg, test)
pred['test_2'] = np.argmax(sub_pred, axis=1)
pred['test_2'] = pred['test_2'].astype(int)
# Out:
# Downloading:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/579 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# -------------------- 0 --------------------
# Downloading:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias', 'mask_predictions.classifier.weight', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5185162857467053, 'score': 0.7448186586922497}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.463829635405073, 'score': 0.7628871925794274}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4256547996226479, 'score': 0.7818068378480758}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4592001959681511, 'score': 0.7891444358811414}
# save model weight
# -------------------- 1 --------------------
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias', 'mask_predictions.classifier.weight', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5065937930462407, 'score': 0.7432584585910608}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4573225907835306, 'score': 0.7814490989447345}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4311730099074981, 'score': 0.7941318231112182}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.46140434067038927, 'score': 0.7895364775308968}
# -------------------- 2 --------------------
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias', 'mask_predictions.classifier.weight', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5110571110975585, 'score': 0.734543601272696}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4684619746926442, 'score': 0.7649361252521372}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4312538108393125, 'score': 0.7943257807531506}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4529961385757617, 'score': 0.7945214105793451}
# save model weight
# CV: 0.79265
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold0.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold1.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold2.pth
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias', 'mask_predictions.classifier.weight', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias', 'mask_predictions.classifier.weight', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at microsoft/deberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.LayerNorm.weight', 'lm_predictions.lm_head.dense.bias', 'mask_predictions.classifier.bias', 'mask_predictions.LayerNorm.bias', 'mask_predictions.dense.bias', 'mask_predictions.classifier.weight', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.LayerNorm.weight', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.LayerNorm.bias', 'lm_predictions.lm_head.bias']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]

# %%
cfg = setup(Config_third)

# データの読み込み
train = pd.read_csv(os.path.join(cfg.INPUT, 'train.csv'))
test = pd.read_csv(os.path.join(cfg.INPUT, 'test.csv'))

TEXT_COLUMNS = ['goal', 'country', 'duration', 'category1', 'category2', 'html_content']

# tokenizerの読み込み
cfg.tokenizer = AutoTokenizer.from_pretrained(cfg.MODEL_PATH)

train['html_content'] = train[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(train[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)
test['html_content'] = test[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(test[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)

# validationデータの設定
cfg.folds = get_stratifiedkfold(train, 'state', cfg.num_fold, cfg.seed)
cfg.folds.to_csv(os.path.join(cfg.EXP_PREDS, 'folds.csv'))

# BERTの学習
oof_pred_3 = training(cfg, train)
oof_3 = np.argmax(oof_pred_3, axis=1)
oof_3 = oof_3.astype(int)

# BERTの推論
cfg.model_weights = [p for p in sorted(glob(os.path.join(cfg.EXP_MODEL, 'fold*.pth')))]
sub_pred = inferring(cfg, test)
pred['test_3'] = np.argmax(sub_pred, axis=1)
pred['test_3'] = pred['test_3'].astype(int)
# Out:
# Downloading:   0%|          | 0.00/83.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/227k [00:00<?, ?B/s]
# -------------------- 0 --------------------
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5729456882850796, 'score': 0.6931003070869828}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.47386553357629213, 'score': 0.7528409186993122}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.48947398510633733, 'score': 0.7575447570332482}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4770938906015134, 'score': 0.758747334987384}
# save model weight
# -------------------- 1 --------------------
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.570963462193807, 'score': 0.7020833806263056}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5046689171417087, 'score': 0.7508320911551436}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.508648996259652, 'score': 0.7430925857382602}
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.480287484386388, 'score': 0.7655677655677655}
# save model weight
# -------------------- 2 --------------------
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5137447227264086, 'score': 0.7302493267800313}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.47084466604743674, 'score': 0.7610666575609608}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.45555609112095696, 'score': 0.7634049624550172}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.45633809852556256, 'score': 0.7741220125536874}
# save model weight
# CV: 0.76631
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold0.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold1.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold2.pth
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]

# %%
cfg = setup(Config_fourth)

# データの読み込み
train = pd.read_csv(os.path.join(cfg.INPUT, 'train.csv'))
test = pd.read_csv(os.path.join(cfg.INPUT, 'test.csv'))

TEXT_COLUMNS = ['goal', 'country', 'duration', 'category1', 'category2', 'html_content']

# tokenizerの読み込み
cfg.tokenizer = AutoTokenizer.from_pretrained(cfg.MODEL_PATH)

train['html_content'] = train[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(train[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)
test['html_content'] = test[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(test[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)

# validationデータの設定
cfg.folds = get_stratifiedkfold(train, 'state', cfg.num_fold, cfg.seed)
cfg.folds.to_csv(os.path.join(cfg.EXP_PREDS, 'folds.csv'))

# BERTの学習
oof_pred_4 = training(cfg, train)
oof_4 = np.argmax(oof_pred_4, axis=1)
oof_4 = oof_4.astype(int)

# BERTの推論
cfg.model_weights = [p for p in sorted(glob(os.path.join(cfg.EXP_MODEL, 'fold*.pth')))]
sub_pred = inferring(cfg, test)
pred['test_4'] = np.argmax(sub_pred, axis=1)
pred['test_4'] = pred['test_4'].astype(int)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# -------------------- 0 --------------------
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5096489050809074, 'score': 0.7492460449765536}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4393390531049055, 'score': 0.7750069025621185}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.472010713874125, 'score': 0.7766172506738545}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4967901285956888, 'score': 0.7882226014615058}
# save model weight
# -------------------- 1 --------------------
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.5612983119254019, 'score': 0.6956436532370736}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.42998969321157415, 'score': 0.7993881097901021}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.47088516868797003, 'score': 0.7846342906730746}
# # ============ start epoch:3 ============== #
#   0%|          | 0/203 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4691336951127239, 'score': 0.8037853526577309}
# save model weight
# -------------------- 2 --------------------
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# # ============ start epoch:0 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4863256570060232, 'score': 0.7577902644760144}
# save model weight
# # ============ start epoch:1 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.42604866698772453, 'score': 0.8081347882625658}
# save model weight
# # ============ start epoch:2 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.4262451507582681, 'score': 0.8102413812508849}
# save model weight
# # ============ start epoch:3 ============== #
#   0%|          | 0/204 [00:00<?, ?it/s]
#   0%|          | 0/102 [00:00<?, ?it/s]
# {'val_loss': 0.45894803204055656, 'score': 0.8110134527798776}
# save model weight
# CV: 0.80101
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold0.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold1.pth
# /content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/test-10-bert-deberta-base-epoch10/model/fold2.pth
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/307 [00:00<?, ?it/s]

# %%
cfg = setup(Config_fifth)

# データの読み込み
train = pd.read_csv(os.path.join(cfg.INPUT, 'train.csv'))
test = pd.read_csv(os.path.join(cfg.INPUT, 'test.csv'))

TEXT_COLUMNS = ['goal', 'country', 'duration', 'category1', 'category2', 'html_content']

# tokenizerの読み込み
cfg.tokenizer = AutoTokenizer.from_pretrained(cfg.MODEL_PATH)

train['html_content'] = train[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(train[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)
test['html_content'] = test[TEXT_COLUMNS[0]].fillna('NAN').astype(str).str.cat(test[TEXT_COLUMNS[1:]].fillna('NAN').astype(str), sep=cfg.tokenizer.sep_token)

train['html_content'] = cleaning(train['html_content'])
test['html_content'] = cleaning(test['html_content'])

# validationデータの設定
cfg.folds = get_stratifiedkfold(train, 'state', cfg.num_fold, cfg.seed)
cfg.folds.to_csv(os.path.join(cfg.EXP_PREDS, 'folds.csv'))

# BERTの学習
oof_pred_5 = training(cfg, train)
oof_5 = np.argmax(oof_pred_5, axis=1)
oof_5 = oof_5.astype(int)

# BERTの推論
cfg.model_weights = [p for p in sorted(glob(os.path.join(cfg.EXP_MODEL, 'fold*.pth')))]
sub_pred = inferring(cfg, test)
pred['test_5'] = np.argmax(sub_pred, axis=1)
pred['test_5'] = pred['test_5'].astype(int)

# %%
pred['test_5'] = np.argmax(sub_pred, axis=1)
pred['test_5'] = pred['test_5'].astype(int)

# %%
class MyHTMLParser(HTMLParser):
    def __init__(self):
        self.count = defaultdict(int)
        super().__init__()

    def handle_starttag(self, tag, attrs):
        self.count[tag] += 1

    def handle_startendtag(self, tag, attrs):
        self.count[tag] += 1

def count_tags(html):
    parser = MyHTMLParser()
    parser.feed(html)
    return parser.count
    

# class TransformerBlock(AbstractBaseBlock):
#     def __init__(self, col, model_name, max_len=512, batch_size=32, if_exists="pass"):
#         super().__init__(if_exists)
#         self.col = col
#         self.model_name = model_name
#         self.prefix = model_name.replace('/', '_')
#         self.model = SentenceTransformer(model_name)
#         self.model.max_seq_length = max_len
#         self.batch_size = batch_size 

#     def transform(self, input_df):
#         texts = input_df[self.col].to_list()
#         embeddings = self.model.encode(texts, batch_size=self.batch_size, show_progress_bar=True)

#         return pd.DataFrame(embeddings).add_prefix(f'{self.prefix}_')

# %%
train_df = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/test.csv')


n_train = len(train_df)

# tagの出現回数でTF-IDF
whole_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)
whole_tag_df = pd.DataFrame(map(count_tags, whole_df['html_content'])).fillna(0)
tf_trans = TfidfTransformer()
tag_columns = whole_tag_df.columns
whole_tag_df = pd.DataFrame(tf_trans.fit_transform(whole_tag_df).todense(), columns=tag_columns)
whole_df[tag_columns] = whole_tag_df

# 文字特徴量
whole_df['len_html'] = whole_df['html_content'].str.len()
whole_df['raw_text'] = whole_df['html_content'].apply(lambda text: BeautifulSoup(text, 'html.parser').get_text())
whole_df['num_word'] = whole_df['raw_text'].str.split().str.len()
whole_df['num_tag'] = whole_tag_df.sum(axis=1)

# goalの分割
whole_df[['goal1', 'goal2']] = whole_df['goal'].str.split('-', expand=True)
whole_df['goal1'] = whole_df['goal1'].str.rstrip('+').fillna(-100).astype(int)
whole_df['goal2'] = whole_df['goal2'].str.rstrip('+').fillna(-100).astype(int)
whole_df['goal_diff'] = whole_df['goal2'] - whole_df['goal1']

categorical_features = ['country', 'category1', 'category2', 'goal1', 'goal2']

for column in categorical_features:
  target_column = whole_df[column]
  le = LabelEncoder()
  le.fit(target_column)
  label_encoded_column = le.transform(target_column)
  whole_df[column] = pd.Series(label_encoded_column).astype('int')

train_df = whole_df.iloc[:n_train]
test_df = whole_df.iloc[n_train:] #.drop(columns=TARGET).reset_index(drop=True)

# %%
pd.DataFrame(oof_1).to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_1_10.csv', index=None, header=None)
pd.DataFrame(oof_2).to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_2_10.csv', index=None, header=None)
pd.DataFrame(oof_3).to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_3_10.csv', index=None, header=None)
pd.DataFrame(oof_4).to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_4_10.csv', index=None, header=None)
pd.DataFrame(oof_5).to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_5_10.csv', index=None, header=None)

# %%
pred.to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/pred_test_10.csv', index=None, header=None)

# %%
oof_1 = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_1_10.csv', header=None)
oof_2 = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_2_10.csv', header=None)
oof_3 = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_3_10.csv', header=None)
oof_4 = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_4_10.csv', header=None)
oof_5 = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/oof_5_10.csv', header=None)

oof_6 = np.load('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Oututput/test-11-deberta-large-epoch5/preds/oof_pred.npy')
oof_6 = np.argmax(oof_6, axis=1)
oof_6 = oof_6.astype(int)

oof_7 = np.load('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Oututput/test-13-deberta-large-epoch5/preds/oof_pred.npy')
oof_7 = np.argmax(oof_7, axis=1)
oof_7 = oof_7.astype(int)


pred = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/pred_test_10.csv', header=None)
# pred_6 = np.load('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Oututput/test-13-deberta-large-epoch5/preds/sub_pred.npy')
# # pred_6 = np.argmax(pred_6, axis=1)
# pred['test_6'] = np.argmax(pred_6, axis=1)
# pred['test_6'] = pred['test_6'].astype(int)

# pred_7 = np.load('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Oututput/test-11-deberta-large-epoch5/preds/sub_pred.npy')
# # pred_7 = np.argmax(pred_7, axis=1)
# pred['test_7'] = np.argmax(pred_7, axis=1)
# pred['test_7'] = pred['test_7'].astype(int)

# %%
a = pd.DataFrame([0])

# %%
a
# Out:
#    0
# 0  0

# %%
oof_1= pd.concat([a, oof_1]).reset_index(drop=True)
oof_2= pd.concat([a, oof_2]).reset_index(drop=True)
oof_3= pd.concat([a, oof_3]).reset_index(drop=True)
oof_4= pd.concat([a, oof_4]).reset_index(drop=True)

# %%
pred
# Out:
#                0  1  2  3  4  5  6  7  8
# 0     test_00000  1  1  1  1  1  1  1  1
# 1     test_00001  0  1  1  1  1  1  1  1
# 2     test_00002  0  1  1  1  1  1  1  1
# 3     test_00003  0  0  0  0  0  0  0  0
# 4     test_00004  1  0  0  0  0  0  0  0
# ...          ... .. .. .. .. .. .. .. ..
# 9795  test_09795  0  1  1  0  1  1  1  1
# 9796  test_09796  0  1  1  1  1  1  1  1
# 9797  test_09797  1  0  0  0  0  0  0  0
# 9798  test_09798  0  0  1  1  1  1  1  1
# 9799  test_09799  0  1  1  1  1  1  1  1
#
# [9800 rows x 9 columns]

# %%
train_df['pred1'] = oof_1
train_df['pred2'] = oof_2
train_df['pred3'] = oof_3
train_df['pred4'] = oof_4
train_df['pred5'] = oof_5
train_df['pred6'] = oof_6
train_df['pred7'] = oof_7
# train_df['pred1'] = train_df['pred1'].astype(int)


test_df['pred1'] = list(map(int, pred[2]))
test_df['pred2'] = list(map(int, pred[3]))
test_df['pred3'] = list(map(int, pred[4]))
test_df['pred4'] = list(map(int, pred[5]))
test_df['pred5'] = list(map(int, pred[6]))
test_df['pred6'] = list(map(int, pred[7]))
test_df['pred7'] = list(map(int, pred[8]))

# 提出用ファイル
# sub.to_csv(os.path.join(cfg.EXP_PREDS, 'submission_bert.csv'), index=False, header=False)

# %%
train_df.head(20)
# Out:
#              id         goal  country  duration  category1  category2  \
# 0   train_00000  20001-21000       21        45          0         77
# 1   train_00001  19001-20000       21        59          7        110
# 2   train_00002    2001-3000       21        38          0         87
# 3   train_00003    1001-2000       21        30          0         77
# 4   train_00004    1001-2000       21        29          6        139
# 5   train_00005    4001-5000       21        45         14         95
# 6   train_00006    2001-3000        3        30         10         22
# 7   train_00007    2001-3000       21        31          0        102
# 8   train_00008       1-1000       21        30         10         76
# 9   train_00009  13001-14000       21        31         10         28
# 10  train_00010       1-1000        8        15         13         33
# 11  train_00011  34001-35000       21        35          5         52
# 12  train_00012  15001-16000       21        29         12         10
# 13  train_00013       1-1000       21        30          5          2
# 14  train_00014       1-1000       21        40         12         14
# 15  train_00015    2001-3000       21        30          0         31
# 16  train_00016    3001-4000        9        30          9        137
# 17  train_00017  11001-12000       21        30          7         36
# 18  train_00018  12001-13000       21        28          9        137
# 19  train_00019       1-1000       21        30         12         48
#
#                                          html_content  state       div  \
# 0   <div class="contents"><div><p><a href="http://...    1.0  0.199318
# 1   <div class="contents"><div><p>Cultural Pretzel...    0.0  0.412459
# 2   <div class="contents"><div><p>I want to perfor...    0.0  0.158952
# 3   <div class="contents"><div><div class="templat...    1.0  0.355376
# 4   <div class="contents"><div><p>The story of the...    1.0  0.318030
# 5   <div class="contents"><div><p>L.U.N.A. (Love, ...    0.0  0.307647
# 6   <div class="contents"><div><p>The Crimson Stri...    1.0  0.436378
# 7   <div class="contents"><div><p> The <span class...    0.0  0.479027
# 8   <div class="contents"><div><p>We are At The Ki...    0.0  0.888858
# 9   <div class="contents"><div><h1 class="page-anc...    1.0  0.049309
# 10  <div class="contents"><div><h1 class="page-anc...    1.0  0.406133
# 11  <div class="contents"><div><p>There are 319 ki...    0.0  0.328018
# 12  <div class="contents"><div><p>For some people ...    0.0  0.366538
# 13  <div class="contents"><div><div class="templat...    1.0  0.227268
# 14  <div class="contents"><div><div class="templat...    0.0  0.657099
# 15  <div class="contents"><div><p>The product I've...    0.0  0.888858
# 16  <div class="contents"><div><p>I am interested ...    0.0  0.034760
# 17  <div class="contents"><div><h1 class="page-anc...    1.0  0.147018
# 18  <div class="contents"><div><h1 class="page-anc...    1.0  0.214144
# 19  <div class="contents"><div><p>The Book is curr...    1.0  0.888858
#
#            p  ...  goal1  goal2  goal_diff  pred1  pred2  pred3  pred4  pred5  \
# 0   0.256858  ...     20     21        999      0      0      0      0      0
# 1   0.637834  ...     19     20        999      0      0      0      0      0
# 2   0.901292  ...      2      3        999      1      1      1      1      1
# 3   0.152655  ...      1      2        999      1      1      1      1      1
# 4   0.136613  ...      1      2        999      1      1      1      1      1
# 5   0.951501  ...      4      5        999      1      1      1      1      1
# 6   0.899764  ...      2      3        999      1      1      1      1      1
# 7   0.740776  ...      2      3        999      1      1      1      1      1
# 8   0.458182  ...      0      1        999      1      0      0      1      1
# 9   0.432100  ...     13     14        999      1      1      1      1      1
# 10  0.084954  ...      0      1        999      1      0      1      1      0
# 11  0.387357  ...     34     35        999      0      0      0      0      0
# 12  0.090691  ...     15     16        999      0      1      1      0      0
# 13  0.390501  ...      0      1        999      1      1      1      1      1
# 14  0.069480  ...      0      1        999      1      1      1      0      1
# 15  0.458182  ...      2      3        999      0      0      0      0      0
# 16  0.179176  ...      3      4        999      0      0      0      0      0
# 17  0.227352  ...     11     12        999      1      1      1      1      0
# 18  0.325899  ...     12     13        999      1      0      0      0      1
# 19  0.458182  ...      0      1        999      1      1      1      1      1
#
#     pred6  pred7
# 0       0      0
# 1       0      0
# 2       1      1
# 3       1      1
# 4       1      1
# 5       0      1
# 6       1      1
# 7       1      1
# 8       0      0
# 9       1      1
# 10      1      0
# 11      0      0
# 12      0      1
# 13      1      1
# 14      0      1
# 15      0      0
# 16      0      0
# 17      1      1
# 18      0      0
# 19      1      0
#
# [20 rows x 53 columns]

# %%
train_df.isnull().sum()
# Out:
# id              0
# goal            0
# country         0
# duration        0
# category1       0
# category2       0
# html_content    0
# state           0
# div             0
# p               0
# a               0
# ul              0
# li              0
# figure          0
# img             0
# span            0
# br              0
# h1              0
# figcaption      0
# i               0
# video           0
# source          0
# button          0
# svg             0
# g               0
# polygon         0
# animate         0
# use             0
# time            0
# iframe          0
# audio           0
# ol              0
# h3              0
# style           0
# param           0
# track           0
# h2              0
# embed           0
# input           0
# len_html        0
# raw_text        0
# num_word        0
# num_tag         0
# goal1           0
# goal2           0
# goal_diff       0
# pred1           0
# pred2           0
# pred3           0
# pred4           0
# pred5           0
# pred6           0
# pred7           0
# dtype: int64

# %%
train_df.columns
# Out:
# Index(['id', 'goal', 'country', 'duration', 'category1', 'category2',
#        'html_content', 'state', 'div', 'p', 'a', 'ul', 'li', 'figure', 'img',
#        'span', 'br', 'h1', 'figcaption', 'i', 'video', 'source', 'button',
#        'svg', 'g', 'polygon', 'animate', 'use', 'time', 'iframe', 'audio',
#        'ol', 'h3', 'style', 'param', 'track', 'h2', 'embed', 'input',
#        'len_html', 'raw_text', 'num_word', 'num_tag', 'goal1', 'goal2',
#        'goal_diff', 'pred1', 'pred2', 'pred3', 'pred4', 'pred5', 'pred6',
#        'pred7'],
#       dtype='object')

# %%
class cfg:
  n_splits = 4

  seed = 123

  num_round = 100

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'learning_rate': 0.002,
    'num_leaves': 64,
    'm_estimators': 100000,
    'num_iterations': 1000000,
    'early_stopping_rounds': 50,
    'random_state': cfg.seed,
    'importance_type': 'gain',
    'feature_fraction': 0.5,
    'lambda_l1': 15,
    'lambda_l2': 15,
}

# %%
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred2', 'pred3', 'pred4', 'pred6', 'pred7'] + tag_columns.to_list() #0.816
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred2', 'pred3', 'pred6', 'pred7'] + tag_columns.to_list() #0.816
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred3', 'pred6', 'pred7'] + tag_columns.to_list() #0.812
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2', 'pred3', 'pred4'] + tag_columns.to_list() #0.826
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2', 'pred3', 'pred4', 'pred6', 'pred7'] + tag_columns.to_list() #0.823
cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2', 'pred3', 'pred4', 'pred5', 'pred6', 'pred7'] + tag_columns.to_list() #0.831
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2', 'pred3', 'pred4', 'pred5'] + tag_columns.to_list() #0.828
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2', 'pred3', 'pred4', 'pred5', 'pred6'] + tag_columns.to_list() #0.829
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2', 'pred3', 'pred4', 'pred5', 'pred7'] + tag_columns.to_list() #0.831
x_train = train_df[cols]
y_train = train_df['state']
id_train = train_df['id']


cv = list(StratifiedKFold(n_splits=cfg.n_splits, shuffle=True, random_state=cfg.seed).split(x_train, y_train))


metrics = []
imp = pd.DataFrame()

# for column in categorical_features:
#   target_column = x_train[column]
#   le = LabelEncoder()
#   le.fit(target_column)
#   label_encoded_column = le.transform(target_column)
#   x_train[column] = pd.Series(label_encoded_column).astype('category')

# %%
for nfold in range(cfg.n_splits):
  print('-'*20, nfold, '-'*20)
  idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
  x_tr, y_tr = x_train.loc[idx_tr], y_train.loc[idx_tr]
  x_va, y_va = x_train.loc[idx_va], y_train.loc[idx_va]
  print(x_tr.shape, y_tr.shape)
  print(x_va.shape, y_va.shape)

  lgb_tr = lgb.Dataset(x_tr, y_tr)
  lgb_va = lgb.Dataset(x_va, y_va)

  lgb_results = {}
  model = lgb.train(params, lgb_tr, num_boost_round=cfg.num_round,
                    valid_names=['train', 'valid'],
                    valid_sets=[lgb_tr, lgb_va])

  y_tr_pred = model.predict(x_tr)
  y_va_pred = model.predict(x_va)
  y_tr_pred = np.where(y_tr_pred > 0.5, 1, 0)
  y_va_pred = np.where(y_va_pred > 0.5, 1, 0)

  print(y_tr)
  print(y_tr_pred)
  f1_tr = f1_score(y_tr, y_tr_pred)
  f1_va = f1_score(y_va, y_va_pred)
  print('[f1 score] tr:{:.4f}, va:{:.4f}'.format(f1_tr, f1_va))
  metrics.append([nfold, f1_tr, f1_va])

print('='*20, 'result', '='*20)
metrics = np.array(metrics)
print(metrics)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# [27439]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27440]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27441]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27442]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27443]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27444]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27445]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27446]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27447]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27448]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27449]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27450]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27451]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27452]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27453]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27454]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27455]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27456]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27457]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27458]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27459]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27460]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27461]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27462]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27463]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27464]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27465]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27466]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27467]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27468]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27469]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27470]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27471]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27472]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27473]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27474]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27475]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27476]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27477]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27478]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27479]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27480]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27481]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27482]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27483]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27484]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27485]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27486]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27487]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27488]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27489]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27490]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27491]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27492]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27493]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27494]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27495]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27496]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27497]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27498]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27499]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27500]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27501]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27502]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27503]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27504]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27505]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27506]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27507]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27508]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27509]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27510]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27511]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27512]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27513]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27514]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27515]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27516]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27517]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27518]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27519]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27520]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27521]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27522]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27523]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27524]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27525]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27526]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27527]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27528]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27529]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27530]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27531]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27532]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27533]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27534]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27535]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27536]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27537]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27538]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27539]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27540]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27541]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27542]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27543]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27544]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27545]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27546]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27547]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27548]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27549]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27550]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27551]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27552]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27553]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27554]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27555]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27556]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27557]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27558]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27559]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27560]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27561]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27562]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27563]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27564]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27565]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27566]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27567]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27568]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27569]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27570]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27571]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27572]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27573]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27574]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27575]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27576]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27577]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27578]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27579]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27580]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27581]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27582]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27583]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27584]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27585]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27586]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27587]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27588]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27589]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27590]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27591]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27592]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27593]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27594]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27595]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27596]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27597]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27598]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27599]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27600]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27601]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27602]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27603]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27604]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27605]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27606]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27607]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27608]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27609]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27610]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27611]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27612]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27613]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27614]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27615]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27616]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27617]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27618]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27619]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27620]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27621]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27622]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27623]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27624]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27625]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27626]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27627]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27628]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27629]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27630]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27631]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27632]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27633]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27634]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27635]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27636]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27637]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27638]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27639]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27640]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27641]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27642]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27643]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27644]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27645]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27646]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27647]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27648]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27649]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27650]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27651]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27652]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27653]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27654]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27655]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27656]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27657]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27658]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27659]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27660]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27661]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27662]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27663]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27664]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27665]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27666]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27667]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27668]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27669]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27670]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27671]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27672]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27673]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27674]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27675]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27676]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27677]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27678]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27679]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27680]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27681]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27682]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27683]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27684]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27685]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27686]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27687]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27688]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27689]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27690]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27691]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27692]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27693]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27694]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27695]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27696]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27697]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27698]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27699]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27700]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27701]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27702]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27703]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27704]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27705]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27706]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27707]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27708]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27709]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27710]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27711]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27712]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27713]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27714]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27715]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27716]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27717]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27718]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27719]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27720]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27721]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27722]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27723]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27724]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27725]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27726]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27727]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27728]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27729]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27730]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27731]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27732]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27733]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27734]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27735]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27736]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27737]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27738]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27739]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27740]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27741]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27742]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27743]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27744]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27745]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27746]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27747]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27748]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27749]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27750]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27751]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27752]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27753]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27754]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27755]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27756]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27757]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27758]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27759]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27760]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27761]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27762]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27763]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27764]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27765]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27766]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27767]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27768]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27769]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27770]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27771]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27772]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27773]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27774]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27775]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27776]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27777]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27778]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27779]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27780]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27781]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27782]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27783]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27784]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27785]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27786]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27787]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27788]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27789]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27790]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27791]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27792]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27793]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27794]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27795]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27796]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27797]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27798]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27799]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27800]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27801]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27802]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27803]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27804]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27805]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27806]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27807]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27808]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27809]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27810]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27811]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27812]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27813]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27814]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27815]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27816]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27817]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27818]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27819]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27820]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27821]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27822]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27823]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27824]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27825]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27826]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27827]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27828]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27829]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27830]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27831]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27832]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27833]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27834]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27835]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27836]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27837]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27838]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27839]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27840]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27841]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27842]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27843]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27844]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27845]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27846]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27847]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27848]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27849]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27850]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27851]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27852]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27853]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27854]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27855]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27856]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27857]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27858]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27859]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27860]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27861]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27862]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27863]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27864]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27865]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27866]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27867]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27868]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27869]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27870]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27871]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27872]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27873]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27874]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27875]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27876]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27877]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27878]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27879]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27880]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27881]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27882]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27883]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27884]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27885]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27886]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27887]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27888]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27889]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27890]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27891]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27892]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27893]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27894]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27895]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27896]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27897]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27898]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27899]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27900]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27901]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27902]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27903]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27904]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27905]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27906]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27907]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27908]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27909]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27910]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27911]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27912]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27913]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27914]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27915]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27916]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27917]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27918]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27919]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27920]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27921]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27922]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27923]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27924]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27925]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27926]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27927]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27928]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27929]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27930]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27931]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27932]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27933]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27934]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27935]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27936]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27937]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27938]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27939]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27940]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27941]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27942]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27943]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27944]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27945]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27946]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27947]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27948]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27949]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27950]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27951]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27952]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27953]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27954]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27955]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27956]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27957]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27958]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27959]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27960]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27961]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27962]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27963]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27964]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27965]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27966]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27967]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27968]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27969]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27970]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27971]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27972]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27973]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27974]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27975]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27976]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27977]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27978]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27979]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27980]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27981]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27982]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27983]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27984]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27985]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27986]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27987]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27988]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27989]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27990]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27991]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27992]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27993]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27994]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27995]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27996]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27997]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27998]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [27999]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28000]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28001]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28002]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28003]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28004]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28005]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28006]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28007]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28008]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28009]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28010]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28011]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28012]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28013]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28014]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28015]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28016]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28017]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28018]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28019]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28020]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28021]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28022]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28023]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28024]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28025]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28026]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28027]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28028]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28029]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28030]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28031]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28032]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28033]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28034]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28035]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28036]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28037]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28038]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28039]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28040]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28041]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28042]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28043]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28044]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28045]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28046]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28047]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28048]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28049]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28050]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28051]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28052]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28053]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28054]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28055]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28056]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28057]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28058]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28059]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28060]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28061]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28062]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28063]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28064]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28065]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28066]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28067]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28068]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28069]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28070]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28071]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28072]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28073]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28074]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28075]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28076]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28077]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28078]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28079]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28080]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28081]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28082]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28083]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28084]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28085]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [28086]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# ...
# [32209]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32210]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32211]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32212]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32213]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32214]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32215]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32216]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32217]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32218]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32219]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32220]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32221]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32222]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32223]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32224]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32225]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32226]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32227]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32228]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32229]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32230]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32231]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32232]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32233]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32234]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32235]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32236]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32237]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32238]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32239]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32240]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32241]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32242]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32243]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32244]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32245]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32246]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32247]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32248]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32249]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32250]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32251]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32252]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32253]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32254]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32255]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32256]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32257]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32258]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32259]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32260]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32261]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32262]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32263]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32264]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32265]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32266]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32267]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32268]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32269]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32270]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32271]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32272]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32273]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32274]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32275]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32276]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32277]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32278]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32279]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32280]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32281]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32282]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32283]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32284]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32285]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32286]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32287]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32288]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32289]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32290]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32291]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32292]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32293]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32294]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32295]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32296]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32297]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32298]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32299]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32300]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32301]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32302]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32303]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32304]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32305]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32306]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32307]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32308]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32309]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32310]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32311]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32312]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32313]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32314]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32315]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32316]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32317]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32318]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32319]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32320]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32321]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32322]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32323]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32324]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32325]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32326]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32327]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32328]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32329]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32330]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32331]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32332]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32333]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32334]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32335]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32336]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32337]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32338]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32339]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32340]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32341]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32342]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32343]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32344]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32345]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32346]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32347]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32348]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32349]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32350]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32351]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32352]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32353]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32354]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32355]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32356]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32357]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32358]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32359]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32360]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32361]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32362]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32363]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32364]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32365]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32366]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32367]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32368]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32369]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32370]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32371]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32372]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32373]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32374]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32375]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32376]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32377]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32378]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32379]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32380]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32381]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32382]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32383]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32384]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32385]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32386]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32387]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32388]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32389]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32390]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32391]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32392]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32393]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32394]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32395]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32396]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32397]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32398]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32399]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32400]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32401]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32402]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32403]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32404]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32405]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32406]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32407]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32408]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32409]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32410]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32411]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32412]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32413]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32414]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32415]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32416]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# [32417]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# Early stopping, best iteration is:
# [32367]	train's binary_logloss: 0.368348	valid's binary_logloss: 0.392582
# 0       1.0
# 1       0.0
# 2       0.0
# 3       1.0
# 5       0.0
#        ...
# 9785    0.0
# 9786    0.0
# 9787    0.0
# 9789    1.0
# 9790    0.0
# Name: state, Length: 7344, dtype: float64
# [0 0 1 ... 0 1 0]
# [f1 score] tr:0.8366, va:0.8248
# ==================== result ====================
# [[0.         0.83730374 0.82890976]
#  [1.         0.84002169 0.81751227]
#  [2.         0.84129347 0.81559708]
#  [3.         0.83658537 0.82481752]]

# %%
sub = pd.read_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Input/sample_submit.csv', header=None)
sub
# Out:
#                0  1
# 0     test_00000  1
# 1     test_00001  0
# 2     test_00002  0
# 3     test_00003  0
# 4     test_00004  1
# ...          ... ..
# 9795  test_09795  0
# 9796  test_09796  0
# 9797  test_09797  1
# 9798  test_09798  0
# 9799  test_09799  0
#
# [9800 rows x 2 columns]

# %%
# cols =  ['country', 'category1', 'category2','goal1', 'goal2', 'duration', 'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2','pred3', 'pred4'] + tag_columns.to_list()
x_test = test_df[cols]
id_test = test_df['id']
# categorical_features = ['country', 'category1', 'category2']

# for column in categorical_features:
#   target_column = x_test[column]
#   le_test = LabelEncoder()
#   le_test.fit(target_column)
#   label_test_encoded_column = le_test.transform(target_column)
#   x_test[column] = pd.Series(label_test_encoded_column).astype('category')

y_test_pred = model.predict(x_test)
y_test_pred = np.where(y_test_pred > 0.5, 1, 0)
print(y_test_pred)
df_submit = pd.DataFrame({'id':id_test, 'pred':y_test_pred})
print(df_submit)
df_submit.to_csv('/content/drive/MyDrive/signate/MUFG Data Science Champion Ship/Output/submit_10.csv', index=None, header=None)
# Out:
# [1 1 1 ... 0 1 1]
#                id  pred
# 9791   test_00000     1
# 9792   test_00001     1
# 9793   test_00002     1
# 9794   test_00003     0
# 9795   test_00004     0
# ...           ...   ...
# 19586  test_09795     1
# 19587  test_09796     1
# 19588  test_09797     0
# 19589  test_09798     1
# 19590  test_09799     1
#
# [9800 rows x 2 columns]

# %%
x_test.columns
# Out:
# Index(['country', 'category1', 'category2', 'goal1', 'goal2', 'duration',
#        'goal_diff', 'num_word', 'len_html', 'num_tag', 'pred1', 'pred2',
#        'pred3', 'pred4', 'pred5', 'pred7', 'div', 'p', 'a', 'ul', 'li',
#        'figure', 'img', 'span', 'br', 'h1', 'figcaption', 'i', 'video',
#        'source', 'button', 'svg', 'g', 'polygon', 'animate', 'use', 'time',
#        'iframe', 'audio', 'ol', 'h3', 'style', 'param', 'track', 'h2', 'embed',
#        'input'],
#       dtype='object')

# %%
x_test.dtypes
# Out:
# country         int64
# category1       int64
# category2       int64
# goal1           int64
# goal2           int64
# duration        int64
# goal_diff       int64
# num_word        int64
# len_html        int64
# num_tag       float64
# pred1           int64
# pred2           int64
# pred3           int64
# pred4           int64
# pred5           int64
# pred7           int64
# div           float64
# p             float64
# a             float64
# ul            float64
# li            float64
# figure        float64
# img           float64
# span          float64
# br            float64
# h1            float64
# figcaption    float64
# i             float64
# video         float64
# source        float64
# button        float64
# svg           float64
# g             float64
# polygon       float64
# animate       float64
# use           float64
# time          float64
# iframe        float64
# audio         float64
# ol            float64
# h3            float64
# style         float64
# param         float64
# track         float64
# h2            float64
# embed         float64
# input         float64
# dtype: object

# %%
x_test.isnull().sum()
# Out:
# country       0
# category1     0
# category2     0
# goal1         0
# goal2         0
# duration      0
# goal_diff     0
# num_word      0
# len_html      0
# num_tag       0
# pred1         0
# pred2         0
# pred3         0
# pred4         0
# pred5         0
# pred7         0
# div           0
# p             0
# a             0
# ul            0
# li            0
# figure        0
# img           0
# span          0
# br            0
# h1            0
# figcaption    0
# i             0
# video         0
# source        0
# button        0
# svg           0
# g             0
# polygon       0
# animate       0
# use           0
# time          0
# iframe        0
# audio         0
# ol            0
# h3            0
# style         0
# param         0
# track         0
# h2            0
# embed         0
# input         0
# dtype: int64

# %% [markdown]
# # やったこと
#
# huggingfaceを使ってcolumをすべてtextとして繋げ, debertaで学習しました
#
# # この後にできそうなこと
#
# baseからlargeにする
#
# mask augmentation
#
# 以下のコメントアウト外せばrandomにtokenをmaskして学習するようになります.
#
# ```
#
# # train_transform = RandomMask(tokenizer, mask_prob=0.2) # [MASK] augmentation
#
# # ds['train'].set_transform(train_transform)
#
# ```
#
# HTMLタグをtokenとして追加する
#
# ちゃんと交差検証する
#
# データ多くないのでハイパラ調整する際は交差検証必須だと思います
#
# CVと言いつつhold outしかしてないので5foldとかで回して平均すれば若干精度伸びそうです.
#
# MLM
#
# htmlを文章として扱っているので事前学習が効きそう
#
# AWP, FGM
#
# 大抵のコンペでやれば精度上がる
#
# max_lenの調整
#
# かなり文章が長いものもあるのでどこまで使うかは大事そう
#
# 切り詰める場合にも後半を切り落とすのではなく中間部分を切り落とした方が良いかも
#
# 文章の長さを特徴量としてあげてもいいかも
#
# 大量にアンサンブル
#
# MODEL_NAME変えて色々混ぜれば精度伸びそうです
#
# 疑似ラベル
#
# ハイパラ調整
#
# huggingfaceにはハイパラ調整用のメソッドが用意されてるので使うと楽に調整できそうですhttps://huggingface.co/docs/transformers/v4.21.2/en/main_classes/trainer#transformers.Trainer.hyperparameter_search
#
# # 感想
#
# タスクがシンプルすぎて差別化が難しい気がしています
#
# 全colum文字としても自然に扱えそうなので, GBDTよりも言語モデルが強い気がしています

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-63e1eb76ad76> in <module>
# ----> 1 model.visualize_importance(results['model_save_paths'])
#
# AttributeError: 'Booster' object has no attribute 'visualize_importance'
